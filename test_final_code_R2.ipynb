# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools

# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null

# !apt-get update -qq 2>&1 > /dev/null

# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth

auth.authenticate_user()

from oauth2client.client import GoogleCredentials

creds = GoogleCredentials.get_application_default()

import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL

vcode = getpass.getpass()

# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.27-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Cannot retrieve auth tokens.
# Failure("Unexpected error response: {\n  \"error\": \"invalid_request\",\n  \"error_description\": \"Missing required parameter: code\"\n}")

# %%
# !mkdir -p drive 

# !google-drive-ocamlfuse drive
# Out:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Error: Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force

# %%
# !pwd
# !ls drive
# Out:
# /content

# %%
# !pip3 install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)

# %%
import torch
import math
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms ,models
import torch.nn.functional as F
import time
import os
import torch.backends.cudnn as cudnn

import matplotlib.pyplot as plt

import gc
gc.collect()
torch.cuda.empty_cache()

import os
print(os.getcwd())
# !ls

# 실행시 등장하는 URL을 클릭하여 허용해주면 인증KEY가 나타난다. 복사하여 URL아래 빈칸에 붙여넣으면 마운트에 성공하게된다.
from google.colab import drive
drive.mount('/content/drive')

os.environ["CUDA_VISIBLE_DEVICES"] = '0'                # GPU Number 
start_time = time.time()
batch_size = 15
learning_rate = 0.001
root_dir = 'drive/MyDrive/app/cifar10/'
default_directory = 'drive/MyDrive/app/torch/save_models'

def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
  
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet152
        """
        model_ft = models.resnet152(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299
    elif model_name == "efficient":
      """ efficientNet"""
      # !pip install efficientnet_pytorch
      from efficientnet_pytorch import EfficientNet

      model_ft = EfficientNet.from_pretrained('efficientnet-b3')
      set_parameter_requires_grad(model_ft, feature_extract)
      model_ft ._fc= torch.nn.Linear(in_features=model_ft._fc.in_features, out_features=num_classes, bias=True)
      input_size = 224

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# Initialize the model for this run
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "resnet"

# Number of classes in the dataset
num_classes = 10

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = False

model_resnet, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "efficient"

# Number of classes in the dataset
num_classes = 10

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = False

model_efficient, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)



# Data Augmentation
transform_train = transforms.Compose([
#    transforms.RandomHorizontalFlip(),                  # right and left flip
#    transforms.Resize(255, interpolation=2),
    transforms.Resize(input_size, interpolation=2),
#    transforms.RandomCrop(input_size, padding=16),               # Random Position Crop
#    transforms.RandomHorizontalFlip(),
#    transforms.RandomRotation(3),
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

transform_test = transforms.Compose([
    transforms.Resize(input_size, interpolation=2),
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

# automatically download
'''
nonaugment_dataset = datasets.CIFAR10(root=root_dir,
                                 train=False,
                                 download=True)
'''
train_dataset = datasets.CIFAR10(root=root_dir,
                                 train=True,
                                 transform=transform_train,
                                 download=True)

test_dataset = datasets.CIFAR10(root=root_dir,
                                train=False,
                                transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True,            # at Training Procedure, Data Shuffle = True
                                           num_workers=1)           # CPU loader number

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False,            # at Test Procedure, Data Shuffle = False
                                          num_workers=1)            # CPU loader number
'''
imgs = torch.stack((*[nonaugment_dataset[i][0] for i in range(10)], *[train_dataset[i][0] for i in range(10)]))

imgs.shape
grid = torchvision.utils.make_grid(imgs, nrow=10)
transforms.ToPILImage()(grid)
'''

#do test


class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB, input):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB
        
        # Create new classifier
        self.classifier = nn.Linear(input*2, 10)
        
    def forward(self, x):
        out1 = self.modelA(x)
        out2 = self.modelB(x)

        x = torch.cat((out1, out2), dim=1)
        
        out = self.classifier(x)
        return out


model = MyEnsemble(model_resnet, model_efficient, 10)
'''
for param in model.parameters():
  param.requires_grad = False

for param in model.classifier.parameters():
  param.requires_grad = True
'''
#optimizer = optim.Adam(model.parameters(), learning_rate, weight_decay=1e-4)
optimizer = optim.SGD(model.parameters(), learning_rate,
                      momentum=0.9,
                      weight_decay=1e-4,
                      nesterov=True)
criterion = nn.CrossEntropyLoss()

if torch.cuda.device_count() > 0:
    print("USE", torch.cuda.device_count(), "GPUs!")
    model = nn.DataParallel(model).cuda()
    cudnn.benchmark = True
else:
    print("USE ONLY CPU!")

#
#val_losses = []
#train_losses = []


def train(epoch):
    model.train()
    train_loss = 0 
    total = 0
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(output.data, 1)

        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
        if batch_idx % 10 == 0:
            print('Epoch: {} | Batch_idx: {} |  Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
                  .format(epoch, batch_idx, train_loss / (batch_idx + 1), 100. * correct / total, correct, total))
            
    #
    #train_losses.append(train_loss)


def test():
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        outputs = model(data)
        loss = criterion(outputs, target)

        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
    print('# TEST : Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
          .format(test_loss / (batch_idx + 1), 100. * correct / total, correct, total))
    #
    #val_losses.append(test_loss))


def save_checkpoint(directory, state, filename='final_R2_latest.tar.gz'):

    if not os.path.exists(directory):
        os.makedirs(directory)

    model_filename = os.path.join(directory, filename)
    torch.save(state, model_filename)
    print("=> saving checkpoint")

def load_checkpoint(directory, filename='final_R2_latest.tar.gz'):

    model_filename = os.path.join(directory, filename)
    if os.path.exists(model_filename):
        print("=> loading checkpoint")
        state = torch.load(model_filename)
        return state
    else:
        return None

start_epoch = 0

checkpoint = load_checkpoint(default_directory)
if not checkpoint:
    pass
else:
    start_epoch = checkpoint['epoch'] + 1
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])

for epoch in range(start_epoch, 20):

    if epoch < 13:
        lr = learning_rate
    elif epoch < 18:
        lr = learning_rate * 0.1
    else:
        lr = learning_rate * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    train(epoch)
    save_checkpoint(default_directory, {
        'epoch': epoch,
        'model': model,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
    })
    test()  

now = time.gmtime(time.time() - start_time)
print('{} hours {} mins {} secs for training'.format(now.tm_hour, now.tm_min, now.tm_sec))

'''
#plot
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(val_losses,label="val")
plt.plot(train_losses,label="train")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
'''
# Out:
# /content
# sample_data
# Mounted at /content/drive
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (4.2.0)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=0a71b337383da06b3f486dc570e0217c64823a84e7ce5f03e169e44382229681
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b3-5fb5a3c3.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b3-5fb5a3c3.pth
#   0%|          | 0.00/47.1M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b3
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Files already downloaded and verified
# USE 1 GPUs!
# => loading checkpoint
# Epoch: 16 | Batch_idx: 0 |  Loss: (0.0001) | Acc: (100.00%) (15/15)
# Epoch: 16 | Batch_idx: 10 |  Loss: (0.0003) | Acc: (100.00%) (165/165)
# Epoch: 16 | Batch_idx: 20 |  Loss: (0.0007) | Acc: (100.00%) (315/315)
# Epoch: 16 | Batch_idx: 30 |  Loss: (0.0009) | Acc: (100.00%) (465/465)
# Epoch: 16 | Batch_idx: 40 |  Loss: (0.0008) | Acc: (100.00%) (615/615)
# Epoch: 16 | Batch_idx: 50 |  Loss: (0.0007) | Acc: (100.00%) (765/765)
# Epoch: 16 | Batch_idx: 60 |  Loss: (0.0006) | Acc: (100.00%) (915/915)
# Epoch: 16 | Batch_idx: 70 |  Loss: (0.0006) | Acc: (100.00%) (1065/1065)
# Epoch: 16 | Batch_idx: 80 |  Loss: (0.0005) | Acc: (100.00%) (1215/1215)
# Epoch: 16 | Batch_idx: 90 |  Loss: (0.0007) | Acc: (100.00%) (1365/1365)
# Epoch: 16 | Batch_idx: 100 |  Loss: (0.0007) | Acc: (100.00%) (1515/1515)
# Epoch: 16 | Batch_idx: 110 |  Loss: (0.0006) | Acc: (100.00%) (1665/1665)
# Epoch: 16 | Batch_idx: 120 |  Loss: (0.0014) | Acc: (99.94%) (1814/1815)
# Epoch: 16 | Batch_idx: 130 |  Loss: (0.0013) | Acc: (99.95%) (1964/1965)
# Epoch: 16 | Batch_idx: 140 |  Loss: (0.0012) | Acc: (99.95%) (2114/2115)
# Epoch: 16 | Batch_idx: 150 |  Loss: (0.0012) | Acc: (99.96%) (2264/2265)
# Epoch: 16 | Batch_idx: 160 |  Loss: (0.0012) | Acc: (99.96%) (2414/2415)
# Epoch: 16 | Batch_idx: 170 |  Loss: (0.0011) | Acc: (99.96%) (2564/2565)
# Epoch: 16 | Batch_idx: 180 |  Loss: (0.0011) | Acc: (99.96%) (2714/2715)
# Epoch: 16 | Batch_idx: 190 |  Loss: (0.0011) | Acc: (99.97%) (2864/2865)
# Epoch: 16 | Batch_idx: 200 |  Loss: (0.0011) | Acc: (99.97%) (3014/3015)
# Epoch: 16 | Batch_idx: 210 |  Loss: (0.0010) | Acc: (99.97%) (3164/3165)
# Epoch: 16 | Batch_idx: 220 |  Loss: (0.0011) | Acc: (99.97%) (3314/3315)
# Epoch: 16 | Batch_idx: 230 |  Loss: (0.0011) | Acc: (99.97%) (3464/3465)
# Epoch: 16 | Batch_idx: 240 |  Loss: (0.0011) | Acc: (99.97%) (3614/3615)
# Epoch: 16 | Batch_idx: 250 |  Loss: (0.0011) | Acc: (99.97%) (3764/3765)
# Epoch: 16 | Batch_idx: 260 |  Loss: (0.0010) | Acc: (99.97%) (3914/3915)
# Epoch: 16 | Batch_idx: 270 |  Loss: (0.0010) | Acc: (99.98%) (4064/4065)
# Epoch: 16 | Batch_idx: 280 |  Loss: (0.0010) | Acc: (99.98%) (4214/4215)
# Epoch: 16 | Batch_idx: 290 |  Loss: (0.0010) | Acc: (99.98%) (4364/4365)
# Epoch: 16 | Batch_idx: 300 |  Loss: (0.0009) | Acc: (99.98%) (4514/4515)
# Epoch: 16 | Batch_idx: 310 |  Loss: (0.0009) | Acc: (99.98%) (4664/4665)
# Epoch: 16 | Batch_idx: 320 |  Loss: (0.0009) | Acc: (99.98%) (4814/4815)
# Epoch: 16 | Batch_idx: 330 |  Loss: (0.0010) | Acc: (99.98%) (4964/4965)
# Epoch: 16 | Batch_idx: 340 |  Loss: (0.0009) | Acc: (99.98%) (5114/5115)
# Epoch: 16 | Batch_idx: 350 |  Loss: (0.0009) | Acc: (99.98%) (5264/5265)
# Epoch: 16 | Batch_idx: 360 |  Loss: (0.0009) | Acc: (99.98%) (5414/5415)
# Epoch: 16 | Batch_idx: 370 |  Loss: (0.0009) | Acc: (99.98%) (5564/5565)
# Epoch: 16 | Batch_idx: 380 |  Loss: (0.0011) | Acc: (99.97%) (5713/5715)
# Epoch: 16 | Batch_idx: 390 |  Loss: (0.0011) | Acc: (99.97%) (5863/5865)
# Epoch: 16 | Batch_idx: 400 |  Loss: (0.0011) | Acc: (99.97%) (6013/6015)
# Epoch: 16 | Batch_idx: 410 |  Loss: (0.0011) | Acc: (99.97%) (6163/6165)
# Epoch: 16 | Batch_idx: 420 |  Loss: (0.0011) | Acc: (99.97%) (6313/6315)
# Epoch: 16 | Batch_idx: 430 |  Loss: (0.0010) | Acc: (99.97%) (6463/6465)
# Epoch: 16 | Batch_idx: 440 |  Loss: (0.0010) | Acc: (99.97%) (6613/6615)
# Epoch: 16 | Batch_idx: 450 |  Loss: (0.0010) | Acc: (99.97%) (6763/6765)
# Epoch: 16 | Batch_idx: 460 |  Loss: (0.0010) | Acc: (99.97%) (6913/6915)
# Epoch: 16 | Batch_idx: 470 |  Loss: (0.0010) | Acc: (99.97%) (7063/7065)
# Epoch: 16 | Batch_idx: 480 |  Loss: (0.0010) | Acc: (99.97%) (7213/7215)
# Epoch: 16 | Batch_idx: 490 |  Loss: (0.0010) | Acc: (99.97%) (7363/7365)
# Epoch: 16 | Batch_idx: 500 |  Loss: (0.0010) | Acc: (99.97%) (7513/7515)
# Epoch: 16 | Batch_idx: 510 |  Loss: (0.0010) | Acc: (99.97%) (7663/7665)
# Epoch: 16 | Batch_idx: 520 |  Loss: (0.0010) | Acc: (99.97%) (7813/7815)
# Epoch: 16 | Batch_idx: 530 |  Loss: (0.0010) | Acc: (99.97%) (7963/7965)
# Epoch: 16 | Batch_idx: 540 |  Loss: (0.0010) | Acc: (99.98%) (8113/8115)
# Epoch: 16 | Batch_idx: 550 |  Loss: (0.0010) | Acc: (99.98%) (8263/8265)
# Epoch: 16 | Batch_idx: 560 |  Loss: (0.0010) | Acc: (99.98%) (8413/8415)
# Epoch: 16 | Batch_idx: 570 |  Loss: (0.0010) | Acc: (99.98%) (8563/8565)
# Epoch: 16 | Batch_idx: 580 |  Loss: (0.0010) | Acc: (99.98%) (8713/8715)
# Epoch: 16 | Batch_idx: 590 |  Loss: (0.0010) | Acc: (99.98%) (8863/8865)
# Epoch: 16 | Batch_idx: 600 |  Loss: (0.0010) | Acc: (99.98%) (9013/9015)
# Epoch: 16 | Batch_idx: 610 |  Loss: (0.0009) | Acc: (99.98%) (9163/9165)
# Epoch: 16 | Batch_idx: 620 |  Loss: (0.0009) | Acc: (99.98%) (9313/9315)
# Epoch: 16 | Batch_idx: 630 |  Loss: (0.0009) | Acc: (99.98%) (9463/9465)
# Epoch: 16 | Batch_idx: 640 |  Loss: (0.0009) | Acc: (99.98%) (9613/9615)
# Epoch: 16 | Batch_idx: 650 |  Loss: (0.0009) | Acc: (99.98%) (9763/9765)
# Epoch: 16 | Batch_idx: 660 |  Loss: (0.0009) | Acc: (99.98%) (9913/9915)
# Epoch: 16 | Batch_idx: 670 |  Loss: (0.0010) | Acc: (99.98%) (10063/10065)
# Epoch: 16 | Batch_idx: 680 |  Loss: (0.0010) | Acc: (99.98%) (10213/10215)
# Epoch: 16 | Batch_idx: 690 |  Loss: (0.0010) | Acc: (99.98%) (10363/10365)
# Epoch: 16 | Batch_idx: 700 |  Loss: (0.0010) | Acc: (99.98%) (10513/10515)
# Epoch: 16 | Batch_idx: 710 |  Loss: (0.0010) | Acc: (99.98%) (10663/10665)
# Epoch: 16 | Batch_idx: 720 |  Loss: (0.0010) | Acc: (99.98%) (10813/10815)
# Epoch: 16 | Batch_idx: 730 |  Loss: (0.0010) | Acc: (99.98%) (10963/10965)
# Epoch: 16 | Batch_idx: 740 |  Loss: (0.0010) | Acc: (99.98%) (11113/11115)
# Epoch: 16 | Batch_idx: 750 |  Loss: (0.0010) | Acc: (99.98%) (11263/11265)
# Epoch: 16 | Batch_idx: 760 |  Loss: (0.0010) | Acc: (99.98%) (11413/11415)
# Epoch: 16 | Batch_idx: 770 |  Loss: (0.0010) | Acc: (99.98%) (11563/11565)
# Epoch: 16 | Batch_idx: 780 |  Loss: (0.0010) | Acc: (99.98%) (11713/11715)
# Epoch: 16 | Batch_idx: 790 |  Loss: (0.0010) | Acc: (99.98%) (11863/11865)
# Epoch: 16 | Batch_idx: 800 |  Loss: (0.0010) | Acc: (99.98%) (12013/12015)
# Epoch: 16 | Batch_idx: 810 |  Loss: (0.0010) | Acc: (99.98%) (12163/12165)
# Epoch: 16 | Batch_idx: 820 |  Loss: (0.0010) | Acc: (99.98%) (12313/12315)
# Epoch: 16 | Batch_idx: 830 |  Loss: (0.0010) | Acc: (99.98%) (12463/12465)
# Epoch: 16 | Batch_idx: 840 |  Loss: (0.0011) | Acc: (99.98%) (12612/12615)
# Epoch: 16 | Batch_idx: 850 |  Loss: (0.0011) | Acc: (99.98%) (12762/12765)
# Epoch: 16 | Batch_idx: 860 |  Loss: (0.0011) | Acc: (99.98%) (12912/12915)
# Epoch: 16 | Batch_idx: 870 |  Loss: (0.0011) | Acc: (99.98%) (13062/13065)
# Epoch: 16 | Batch_idx: 880 |  Loss: (0.0011) | Acc: (99.98%) (13212/13215)
# Epoch: 16 | Batch_idx: 890 |  Loss: (0.0012) | Acc: (99.98%) (13362/13365)
# Epoch: 16 | Batch_idx: 900 |  Loss: (0.0012) | Acc: (99.98%) (13512/13515)
# Epoch: 16 | Batch_idx: 910 |  Loss: (0.0012) | Acc: (99.98%) (13662/13665)
# Epoch: 16 | Batch_idx: 920 |  Loss: (0.0012) | Acc: (99.98%) (13812/13815)
# Epoch: 16 | Batch_idx: 930 |  Loss: (0.0012) | Acc: (99.98%) (13962/13965)
# Epoch: 16 | Batch_idx: 940 |  Loss: (0.0012) | Acc: (99.98%) (14112/14115)
# Epoch: 16 | Batch_idx: 950 |  Loss: (0.0012) | Acc: (99.98%) (14262/14265)
# Epoch: 16 | Batch_idx: 960 |  Loss: (0.0012) | Acc: (99.98%) (14412/14415)
# Epoch: 16 | Batch_idx: 970 |  Loss: (0.0012) | Acc: (99.98%) (14562/14565)
# Epoch: 16 | Batch_idx: 980 |  Loss: (0.0012) | Acc: (99.98%) (14712/14715)
# Epoch: 16 | Batch_idx: 990 |  Loss: (0.0012) | Acc: (99.98%) (14862/14865)
# Epoch: 16 | Batch_idx: 1000 |  Loss: (0.0012) | Acc: (99.98%) (15012/15015)
# Epoch: 16 | Batch_idx: 1010 |  Loss: (0.0012) | Acc: (99.98%) (15162/15165)
# Epoch: 16 | Batch_idx: 1020 |  Loss: (0.0012) | Acc: (99.98%) (15312/15315)
# Epoch: 16 | Batch_idx: 1030 |  Loss: (0.0012) | Acc: (99.98%) (15462/15465)
# Epoch: 16 | Batch_idx: 1040 |  Loss: (0.0012) | Acc: (99.98%) (15612/15615)
# Epoch: 16 | Batch_idx: 1050 |  Loss: (0.0012) | Acc: (99.98%) (15762/15765)
# Epoch: 16 | Batch_idx: 1060 |  Loss: (0.0012) | Acc: (99.98%) (15912/15915)
# Epoch: 16 | Batch_idx: 1070 |  Loss: (0.0012) | Acc: (99.98%) (16062/16065)
# Epoch: 16 | Batch_idx: 1080 |  Loss: (0.0012) | Acc: (99.98%) (16212/16215)
# Epoch: 16 | Batch_idx: 1090 |  Loss: (0.0012) | Acc: (99.98%) (16362/16365)
# Epoch: 16 | Batch_idx: 1100 |  Loss: (0.0012) | Acc: (99.98%) (16512/16515)
# Epoch: 16 | Batch_idx: 1110 |  Loss: (0.0012) | Acc: (99.98%) (16662/16665)
# Epoch: 16 | Batch_idx: 1120 |  Loss: (0.0012) | Acc: (99.98%) (16812/16815)
# Epoch: 16 | Batch_idx: 1130 |  Loss: (0.0012) | Acc: (99.98%) (16962/16965)
# Epoch: 16 | Batch_idx: 1140 |  Loss: (0.0012) | Acc: (99.98%) (17112/17115)
# Epoch: 16 | Batch_idx: 1150 |  Loss: (0.0012) | Acc: (99.98%) (17262/17265)
# Epoch: 16 | Batch_idx: 1160 |  Loss: (0.0012) | Acc: (99.98%) (17412/17415)
# Epoch: 16 | Batch_idx: 1170 |  Loss: (0.0011) | Acc: (99.98%) (17562/17565)
# Epoch: 16 | Batch_idx: 1180 |  Loss: (0.0011) | Acc: (99.98%) (17712/17715)
# Epoch: 16 | Batch_idx: 1190 |  Loss: (0.0011) | Acc: (99.98%) (17862/17865)
# Epoch: 16 | Batch_idx: 1200 |  Loss: (0.0011) | Acc: (99.98%) (18012/18015)
# Epoch: 16 | Batch_idx: 1210 |  Loss: (0.0011) | Acc: (99.98%) (18162/18165)
# Epoch: 16 | Batch_idx: 1220 |  Loss: (0.0011) | Acc: (99.98%) (18312/18315)
# Epoch: 16 | Batch_idx: 1230 |  Loss: (0.0011) | Acc: (99.98%) (18462/18465)
# Epoch: 16 | Batch_idx: 1240 |  Loss: (0.0011) | Acc: (99.98%) (18612/18615)
# Epoch: 16 | Batch_idx: 1250 |  Loss: (0.0011) | Acc: (99.98%) (18762/18765)
# Epoch: 16 | Batch_idx: 1260 |  Loss: (0.0011) | Acc: (99.98%) (18912/18915)
# Epoch: 16 | Batch_idx: 1270 |  Loss: (0.0011) | Acc: (99.98%) (19062/19065)
# Epoch: 16 | Batch_idx: 1280 |  Loss: (0.0011) | Acc: (99.98%) (19212/19215)
# Epoch: 16 | Batch_idx: 1290 |  Loss: (0.0011) | Acc: (99.98%) (19362/19365)
# Epoch: 16 | Batch_idx: 1300 |  Loss: (0.0011) | Acc: (99.98%) (19512/19515)
# Epoch: 16 | Batch_idx: 1310 |  Loss: (0.0011) | Acc: (99.98%) (19662/19665)
# Epoch: 16 | Batch_idx: 1320 |  Loss: (0.0011) | Acc: (99.98%) (19812/19815)
# Epoch: 16 | Batch_idx: 1330 |  Loss: (0.0012) | Acc: (99.98%) (19961/19965)
# Epoch: 16 | Batch_idx: 1340 |  Loss: (0.0012) | Acc: (99.98%) (20111/20115)
# Epoch: 16 | Batch_idx: 1350 |  Loss: (0.0011) | Acc: (99.98%) (20261/20265)
# Epoch: 16 | Batch_idx: 1360 |  Loss: (0.0011) | Acc: (99.98%) (20411/20415)
# Epoch: 16 | Batch_idx: 1370 |  Loss: (0.0011) | Acc: (99.98%) (20561/20565)
# Epoch: 16 | Batch_idx: 1380 |  Loss: (0.0011) | Acc: (99.98%) (20711/20715)
# Epoch: 16 | Batch_idx: 1390 |  Loss: (0.0011) | Acc: (99.98%) (20861/20865)
# Epoch: 16 | Batch_idx: 1400 |  Loss: (0.0012) | Acc: (99.98%) (21011/21015)
# Epoch: 16 | Batch_idx: 1410 |  Loss: (0.0012) | Acc: (99.98%) (21161/21165)
# Epoch: 16 | Batch_idx: 1420 |  Loss: (0.0012) | Acc: (99.98%) (21310/21315)
# Epoch: 16 | Batch_idx: 1430 |  Loss: (0.0012) | Acc: (99.98%) (21460/21465)
# Epoch: 16 | Batch_idx: 1440 |  Loss: (0.0012) | Acc: (99.98%) (21610/21615)
# Epoch: 16 | Batch_idx: 1450 |  Loss: (0.0012) | Acc: (99.98%) (21760/21765)
# Epoch: 16 | Batch_idx: 1460 |  Loss: (0.0012) | Acc: (99.98%) (21910/21915)
# Epoch: 16 | Batch_idx: 1470 |  Loss: (0.0012) | Acc: (99.98%) (22060/22065)
# Epoch: 16 | Batch_idx: 1480 |  Loss: (0.0012) | Acc: (99.98%) (22210/22215)
# Epoch: 16 | Batch_idx: 1490 |  Loss: (0.0012) | Acc: (99.98%) (22360/22365)
# Epoch: 16 | Batch_idx: 1500 |  Loss: (0.0013) | Acc: (99.97%) (22509/22515)
# Epoch: 16 | Batch_idx: 1510 |  Loss: (0.0012) | Acc: (99.97%) (22659/22665)
# Epoch: 16 | Batch_idx: 1520 |  Loss: (0.0012) | Acc: (99.97%) (22809/22815)
# Epoch: 16 | Batch_idx: 1530 |  Loss: (0.0012) | Acc: (99.97%) (22959/22965)
# Epoch: 16 | Batch_idx: 1540 |  Loss: (0.0012) | Acc: (99.97%) (23109/23115)
# Epoch: 16 | Batch_idx: 1550 |  Loss: (0.0012) | Acc: (99.97%) (23259/23265)
# Epoch: 16 | Batch_idx: 1560 |  Loss: (0.0012) | Acc: (99.97%) (23409/23415)
# Epoch: 16 | Batch_idx: 1570 |  Loss: (0.0012) | Acc: (99.97%) (23559/23565)
# Epoch: 16 | Batch_idx: 1580 |  Loss: (0.0012) | Acc: (99.97%) (23709/23715)
# Epoch: 16 | Batch_idx: 1590 |  Loss: (0.0012) | Acc: (99.97%) (23859/23865)
# Epoch: 16 | Batch_idx: 1600 |  Loss: (0.0012) | Acc: (99.98%) (24009/24015)
# Epoch: 16 | Batch_idx: 1610 |  Loss: (0.0012) | Acc: (99.98%) (24159/24165)
# Epoch: 16 | Batch_idx: 1620 |  Loss: (0.0012) | Acc: (99.98%) (24309/24315)
# Epoch: 16 | Batch_idx: 1630 |  Loss: (0.0013) | Acc: (99.97%) (24458/24465)
# Epoch: 16 | Batch_idx: 1640 |  Loss: (0.0013) | Acc: (99.97%) (24608/24615)
# Epoch: 16 | Batch_idx: 1650 |  Loss: (0.0013) | Acc: (99.97%) (24758/24765)
# Epoch: 16 | Batch_idx: 1660 |  Loss: (0.0013) | Acc: (99.97%) (24908/24915)
# Epoch: 16 | Batch_idx: 1670 |  Loss: (0.0013) | Acc: (99.97%) (25058/25065)
# Epoch: 16 | Batch_idx: 1680 |  Loss: (0.0013) | Acc: (99.97%) (25208/25215)
# Epoch: 16 | Batch_idx: 1690 |  Loss: (0.0013) | Acc: (99.97%) (25358/25365)
# Epoch: 16 | Batch_idx: 1700 |  Loss: (0.0013) | Acc: (99.97%) (25508/25515)
# Epoch: 16 | Batch_idx: 1710 |  Loss: (0.0013) | Acc: (99.97%) (25658/25665)
# Epoch: 16 | Batch_idx: 1720 |  Loss: (0.0013) | Acc: (99.97%) (25808/25815)
# Epoch: 16 | Batch_idx: 1730 |  Loss: (0.0013) | Acc: (99.97%) (25958/25965)
# Epoch: 16 | Batch_idx: 1740 |  Loss: (0.0013) | Acc: (99.97%) (26108/26115)
# Epoch: 16 | Batch_idx: 1750 |  Loss: (0.0013) | Acc: (99.97%) (26258/26265)
# Epoch: 16 | Batch_idx: 1760 |  Loss: (0.0013) | Acc: (99.97%) (26408/26415)
# Epoch: 16 | Batch_idx: 1770 |  Loss: (0.0013) | Acc: (99.97%) (26558/26565)
# Epoch: 16 | Batch_idx: 1780 |  Loss: (0.0012) | Acc: (99.97%) (26708/26715)
# Epoch: 16 | Batch_idx: 1790 |  Loss: (0.0012) | Acc: (99.97%) (26858/26865)
# Epoch: 16 | Batch_idx: 1800 |  Loss: (0.0012) | Acc: (99.97%) (27008/27015)
# Epoch: 16 | Batch_idx: 1810 |  Loss: (0.0012) | Acc: (99.97%) (27158/27165)
# Epoch: 16 | Batch_idx: 1820 |  Loss: (0.0012) | Acc: (99.97%) (27308/27315)
# Epoch: 16 | Batch_idx: 1830 |  Loss: (0.0012) | Acc: (99.97%) (27458/27465)
# Epoch: 16 | Batch_idx: 1840 |  Loss: (0.0012) | Acc: (99.97%) (27608/27615)
# Epoch: 16 | Batch_idx: 1850 |  Loss: (0.0012) | Acc: (99.97%) (27758/27765)
# Epoch: 16 | Batch_idx: 1860 |  Loss: (0.0012) | Acc: (99.97%) (27908/27915)
# Epoch: 16 | Batch_idx: 1870 |  Loss: (0.0012) | Acc: (99.98%) (28058/28065)
# Epoch: 16 | Batch_idx: 1880 |  Loss: (0.0012) | Acc: (99.98%) (28208/28215)
# Epoch: 16 | Batch_idx: 1890 |  Loss: (0.0012) | Acc: (99.98%) (28358/28365)
# Epoch: 16 | Batch_idx: 1900 |  Loss: (0.0012) | Acc: (99.98%) (28508/28515)
# Epoch: 16 | Batch_idx: 1910 |  Loss: (0.0012) | Acc: (99.98%) (28658/28665)
# Epoch: 16 | Batch_idx: 1920 |  Loss: (0.0012) | Acc: (99.98%) (28808/28815)
# Epoch: 16 | Batch_idx: 1930 |  Loss: (0.0012) | Acc: (99.98%) (28958/28965)
# Epoch: 16 | Batch_idx: 1940 |  Loss: (0.0012) | Acc: (99.98%) (29108/29115)
# Epoch: 16 | Batch_idx: 1950 |  Loss: (0.0012) | Acc: (99.98%) (29258/29265)
# Epoch: 16 | Batch_idx: 1960 |  Loss: (0.0012) | Acc: (99.98%) (29408/29415)
# Epoch: 16 | Batch_idx: 1970 |  Loss: (0.0012) | Acc: (99.98%) (29558/29565)
# Epoch: 16 | Batch_idx: 1980 |  Loss: (0.0012) | Acc: (99.98%) (29708/29715)
# Epoch: 16 | Batch_idx: 1990 |  Loss: (0.0012) | Acc: (99.98%) (29858/29865)
# Epoch: 16 | Batch_idx: 2000 |  Loss: (0.0012) | Acc: (99.98%) (30008/30015)
# Epoch: 16 | Batch_idx: 2010 |  Loss: (0.0012) | Acc: (99.98%) (30158/30165)
# Epoch: 16 | Batch_idx: 2020 |  Loss: (0.0012) | Acc: (99.98%) (30308/30315)
# Epoch: 16 | Batch_idx: 2030 |  Loss: (0.0012) | Acc: (99.98%) (30458/30465)
# Epoch: 16 | Batch_idx: 2040 |  Loss: (0.0012) | Acc: (99.98%) (30608/30615)
# Epoch: 16 | Batch_idx: 2050 |  Loss: (0.0012) | Acc: (99.98%) (30758/30765)
# Epoch: 16 | Batch_idx: 2060 |  Loss: (0.0012) | Acc: (99.98%) (30908/30915)
# Epoch: 16 | Batch_idx: 2070 |  Loss: (0.0012) | Acc: (99.98%) (31058/31065)
# Epoch: 16 | Batch_idx: 2080 |  Loss: (0.0012) | Acc: (99.97%) (31207/31215)
# Epoch: 16 | Batch_idx: 2090 |  Loss: (0.0012) | Acc: (99.97%) (31357/31365)
# Epoch: 16 | Batch_idx: 2100 |  Loss: (0.0012) | Acc: (99.97%) (31506/31515)
# Epoch: 16 | Batch_idx: 2110 |  Loss: (0.0012) | Acc: (99.97%) (31656/31665)
# Epoch: 16 | Batch_idx: 2120 |  Loss: (0.0012) | Acc: (99.97%) (31806/31815)
# Epoch: 16 | Batch_idx: 2130 |  Loss: (0.0012) | Acc: (99.97%) (31956/31965)
# Epoch: 16 | Batch_idx: 2140 |  Loss: (0.0012) | Acc: (99.97%) (32106/32115)
# Epoch: 16 | Batch_idx: 2150 |  Loss: (0.0012) | Acc: (99.97%) (32256/32265)
# Epoch: 16 | Batch_idx: 2160 |  Loss: (0.0012) | Acc: (99.97%) (32406/32415)
# Epoch: 16 | Batch_idx: 2170 |  Loss: (0.0012) | Acc: (99.97%) (32556/32565)
# Epoch: 16 | Batch_idx: 2180 |  Loss: (0.0012) | Acc: (99.97%) (32706/32715)
# Epoch: 16 | Batch_idx: 2190 |  Loss: (0.0012) | Acc: (99.97%) (32856/32865)
# Epoch: 16 | Batch_idx: 2200 |  Loss: (0.0012) | Acc: (99.97%) (33006/33015)
# Epoch: 16 | Batch_idx: 2210 |  Loss: (0.0012) | Acc: (99.97%) (33156/33165)
# Epoch: 16 | Batch_idx: 2220 |  Loss: (0.0012) | Acc: (99.97%) (33306/33315)
# Epoch: 16 | Batch_idx: 2230 |  Loss: (0.0012) | Acc: (99.97%) (33456/33465)
# Epoch: 16 | Batch_idx: 2240 |  Loss: (0.0012) | Acc: (99.97%) (33606/33615)
# Epoch: 16 | Batch_idx: 2250 |  Loss: (0.0012) | Acc: (99.97%) (33756/33765)
# Epoch: 16 | Batch_idx: 2260 |  Loss: (0.0012) | Acc: (99.97%) (33906/33915)
# Epoch: 16 | Batch_idx: 2270 |  Loss: (0.0012) | Acc: (99.97%) (34056/34065)
# Epoch: 16 | Batch_idx: 2280 |  Loss: (0.0012) | Acc: (99.97%) (34206/34215)
# Epoch: 16 | Batch_idx: 2290 |  Loss: (0.0012) | Acc: (99.97%) (34356/34365)
# Epoch: 16 | Batch_idx: 2300 |  Loss: (0.0012) | Acc: (99.97%) (34506/34515)
# Epoch: 16 | Batch_idx: 2310 |  Loss: (0.0012) | Acc: (99.97%) (34656/34665)
# Epoch: 16 | Batch_idx: 2320 |  Loss: (0.0012) | Acc: (99.97%) (34806/34815)
# Epoch: 16 | Batch_idx: 2330 |  Loss: (0.0012) | Acc: (99.97%) (34956/34965)
# Epoch: 16 | Batch_idx: 2340 |  Loss: (0.0012) | Acc: (99.97%) (35106/35115)
# Epoch: 16 | Batch_idx: 2350 |  Loss: (0.0012) | Acc: (99.97%) (35256/35265)
# Epoch: 16 | Batch_idx: 2360 |  Loss: (0.0012) | Acc: (99.97%) (35406/35415)
# Epoch: 16 | Batch_idx: 2370 |  Loss: (0.0012) | Acc: (99.97%) (35556/35565)
# Epoch: 16 | Batch_idx: 2380 |  Loss: (0.0012) | Acc: (99.97%) (35706/35715)
# Epoch: 16 | Batch_idx: 2390 |  Loss: (0.0012) | Acc: (99.97%) (35856/35865)
# Epoch: 16 | Batch_idx: 2400 |  Loss: (0.0012) | Acc: (99.98%) (36006/36015)
# Epoch: 16 | Batch_idx: 2410 |  Loss: (0.0012) | Acc: (99.98%) (36156/36165)
# Epoch: 16 | Batch_idx: 2420 |  Loss: (0.0012) | Acc: (99.98%) (36306/36315)
# Epoch: 16 | Batch_idx: 2430 |  Loss: (0.0012) | Acc: (99.98%) (36456/36465)
# Epoch: 16 | Batch_idx: 2440 |  Loss: (0.0012) | Acc: (99.98%) (36606/36615)
# Epoch: 16 | Batch_idx: 2450 |  Loss: (0.0012) | Acc: (99.98%) (36756/36765)
# Epoch: 16 | Batch_idx: 2460 |  Loss: (0.0012) | Acc: (99.98%) (36906/36915)
# Epoch: 16 | Batch_idx: 2470 |  Loss: (0.0012) | Acc: (99.98%) (37056/37065)
# Epoch: 16 | Batch_idx: 2480 |  Loss: (0.0012) | Acc: (99.98%) (37206/37215)
# Epoch: 16 | Batch_idx: 2490 |  Loss: (0.0012) | Acc: (99.98%) (37356/37365)
# Epoch: 16 | Batch_idx: 2500 |  Loss: (0.0012) | Acc: (99.98%) (37506/37515)
# Epoch: 16 | Batch_idx: 2510 |  Loss: (0.0012) | Acc: (99.98%) (37656/37665)
# Epoch: 16 | Batch_idx: 2520 |  Loss: (0.0012) | Acc: (99.98%) (37806/37815)
# Epoch: 16 | Batch_idx: 2530 |  Loss: (0.0012) | Acc: (99.98%) (37956/37965)
# Epoch: 16 | Batch_idx: 2540 |  Loss: (0.0012) | Acc: (99.98%) (38106/38115)
# Epoch: 16 | Batch_idx: 2550 |  Loss: (0.0012) | Acc: (99.98%) (38256/38265)
# Epoch: 16 | Batch_idx: 2560 |  Loss: (0.0012) | Acc: (99.98%) (38406/38415)
# Epoch: 16 | Batch_idx: 2570 |  Loss: (0.0012) | Acc: (99.98%) (38556/38565)
# Epoch: 16 | Batch_idx: 2580 |  Loss: (0.0012) | Acc: (99.98%) (38706/38715)
# Epoch: 16 | Batch_idx: 2590 |  Loss: (0.0012) | Acc: (99.98%) (38856/38865)
# Epoch: 16 | Batch_idx: 2600 |  Loss: (0.0012) | Acc: (99.98%) (39006/39015)
# Epoch: 16 | Batch_idx: 2610 |  Loss: (0.0012) | Acc: (99.98%) (39156/39165)
# Epoch: 16 | Batch_idx: 2620 |  Loss: (0.0012) | Acc: (99.98%) (39306/39315)
# Epoch: 16 | Batch_idx: 2630 |  Loss: (0.0012) | Acc: (99.98%) (39456/39465)
# Epoch: 16 | Batch_idx: 2640 |  Loss: (0.0012) | Acc: (99.98%) (39606/39615)
# Epoch: 16 | Batch_idx: 2650 |  Loss: (0.0012) | Acc: (99.98%) (39756/39765)
# Epoch: 16 | Batch_idx: 2660 |  Loss: (0.0012) | Acc: (99.98%) (39906/39915)
# Epoch: 16 | Batch_idx: 2670 |  Loss: (0.0012) | Acc: (99.98%) (40056/40065)
# Epoch: 16 | Batch_idx: 2680 |  Loss: (0.0012) | Acc: (99.98%) (40206/40215)
# Epoch: 16 | Batch_idx: 2690 |  Loss: (0.0012) | Acc: (99.98%) (40356/40365)
# Epoch: 16 | Batch_idx: 2700 |  Loss: (0.0012) | Acc: (99.98%) (40506/40515)
# Epoch: 16 | Batch_idx: 2710 |  Loss: (0.0012) | Acc: (99.98%) (40656/40665)
# Epoch: 16 | Batch_idx: 2720 |  Loss: (0.0012) | Acc: (99.98%) (40806/40815)
# Epoch: 16 | Batch_idx: 2730 |  Loss: (0.0012) | Acc: (99.98%) (40956/40965)
# Epoch: 16 | Batch_idx: 2740 |  Loss: (0.0012) | Acc: (99.98%) (41106/41115)
# Epoch: 16 | Batch_idx: 2750 |  Loss: (0.0012) | Acc: (99.98%) (41256/41265)
# Epoch: 16 | Batch_idx: 2760 |  Loss: (0.0012) | Acc: (99.98%) (41406/41415)
# Epoch: 16 | Batch_idx: 2770 |  Loss: (0.0012) | Acc: (99.98%) (41556/41565)
# Epoch: 16 | Batch_idx: 2780 |  Loss: (0.0012) | Acc: (99.98%) (41706/41715)
# Epoch: 16 | Batch_idx: 2790 |  Loss: (0.0012) | Acc: (99.98%) (41856/41865)
# Epoch: 16 | Batch_idx: 2800 |  Loss: (0.0012) | Acc: (99.98%) (42006/42015)
# Epoch: 16 | Batch_idx: 2810 |  Loss: (0.0012) | Acc: (99.98%) (42156/42165)
# Epoch: 16 | Batch_idx: 2820 |  Loss: (0.0012) | Acc: (99.98%) (42306/42315)
# Epoch: 16 | Batch_idx: 2830 |  Loss: (0.0012) | Acc: (99.98%) (42456/42465)
# Epoch: 16 | Batch_idx: 2840 |  Loss: (0.0011) | Acc: (99.98%) (42606/42615)
# Epoch: 16 | Batch_idx: 2850 |  Loss: (0.0011) | Acc: (99.98%) (42756/42765)
# Epoch: 16 | Batch_idx: 2860 |  Loss: (0.0011) | Acc: (99.98%) (42906/42915)
# Epoch: 16 | Batch_idx: 2870 |  Loss: (0.0012) | Acc: (99.98%) (43056/43065)
# Epoch: 16 | Batch_idx: 2880 |  Loss: (0.0012) | Acc: (99.98%) (43206/43215)
# Epoch: 16 | Batch_idx: 2890 |  Loss: (0.0012) | Acc: (99.98%) (43356/43365)
# Epoch: 16 | Batch_idx: 2900 |  Loss: (0.0012) | Acc: (99.98%) (43506/43515)
# Epoch: 16 | Batch_idx: 2910 |  Loss: (0.0011) | Acc: (99.98%) (43656/43665)
# Epoch: 16 | Batch_idx: 2920 |  Loss: (0.0011) | Acc: (99.98%) (43806/43815)
# Epoch: 16 | Batch_idx: 2930 |  Loss: (0.0011) | Acc: (99.98%) (43956/43965)
# Epoch: 16 | Batch_idx: 2940 |  Loss: (0.0011) | Acc: (99.98%) (44106/44115)
# Epoch: 16 | Batch_idx: 2950 |  Loss: (0.0011) | Acc: (99.98%) (44256/44265)
# Epoch: 16 | Batch_idx: 2960 |  Loss: (0.0011) | Acc: (99.98%) (44406/44415)
# Epoch: 16 | Batch_idx: 2970 |  Loss: (0.0011) | Acc: (99.98%) (44556/44565)
# Epoch: 16 | Batch_idx: 2980 |  Loss: (0.0011) | Acc: (99.98%) (44706/44715)
# Epoch: 16 | Batch_idx: 2990 |  Loss: (0.0011) | Acc: (99.98%) (44856/44865)
# Epoch: 16 | Batch_idx: 3000 |  Loss: (0.0011) | Acc: (99.98%) (45006/45015)
# Epoch: 16 | Batch_idx: 3010 |  Loss: (0.0011) | Acc: (99.98%) (45156/45165)
# Epoch: 16 | Batch_idx: 3020 |  Loss: (0.0011) | Acc: (99.98%) (45306/45315)
# Epoch: 16 | Batch_idx: 3030 |  Loss: (0.0011) | Acc: (99.98%) (45456/45465)
# Epoch: 16 | Batch_idx: 3040 |  Loss: (0.0011) | Acc: (99.98%) (45606/45615)
# Epoch: 16 | Batch_idx: 3050 |  Loss: (0.0011) | Acc: (99.98%) (45756/45765)
# Epoch: 16 | Batch_idx: 3060 |  Loss: (0.0011) | Acc: (99.98%) (45906/45915)
# Epoch: 16 | Batch_idx: 3070 |  Loss: (0.0011) | Acc: (99.98%) (46056/46065)
# Epoch: 16 | Batch_idx: 3080 |  Loss: (0.0011) | Acc: (99.98%) (46206/46215)
# Epoch: 16 | Batch_idx: 3090 |  Loss: (0.0011) | Acc: (99.98%) (46356/46365)
# Epoch: 16 | Batch_idx: 3100 |  Loss: (0.0011) | Acc: (99.98%) (46506/46515)
# Epoch: 16 | Batch_idx: 3110 |  Loss: (0.0011) | Acc: (99.98%) (46656/46665)
# Epoch: 16 | Batch_idx: 3120 |  Loss: (0.0011) | Acc: (99.98%) (46806/46815)
# Epoch: 16 | Batch_idx: 3130 |  Loss: (0.0011) | Acc: (99.98%) (46956/46965)
# Epoch: 16 | Batch_idx: 3140 |  Loss: (0.0011) | Acc: (99.98%) (47106/47115)
# Epoch: 16 | Batch_idx: 3150 |  Loss: (0.0011) | Acc: (99.98%) (47256/47265)
# Epoch: 16 | Batch_idx: 3160 |  Loss: (0.0011) | Acc: (99.98%) (47406/47415)
# Epoch: 16 | Batch_idx: 3170 |  Loss: (0.0011) | Acc: (99.98%) (47556/47565)
# Epoch: 16 | Batch_idx: 3180 |  Loss: (0.0011) | Acc: (99.98%) (47706/47715)
# Epoch: 16 | Batch_idx: 3190 |  Loss: (0.0011) | Acc: (99.98%) (47856/47865)
# Epoch: 16 | Batch_idx: 3200 |  Loss: (0.0011) | Acc: (99.98%) (48006/48015)
# Epoch: 16 | Batch_idx: 3210 |  Loss: (0.0011) | Acc: (99.98%) (48156/48165)
# Epoch: 16 | Batch_idx: 3220 |  Loss: (0.0011) | Acc: (99.98%) (48306/48315)
# Epoch: 16 | Batch_idx: 3230 |  Loss: (0.0011) | Acc: (99.98%) (48456/48465)
# Epoch: 16 | Batch_idx: 3240 |  Loss: (0.0011) | Acc: (99.98%) (48606/48615)
# Epoch: 16 | Batch_idx: 3250 |  Loss: (0.0011) | Acc: (99.98%) (48756/48765)
# Epoch: 16 | Batch_idx: 3260 |  Loss: (0.0011) | Acc: (99.98%) (48906/48915)
# Epoch: 16 | Batch_idx: 3270 |  Loss: (0.0011) | Acc: (99.98%) (49056/49065)
# Epoch: 16 | Batch_idx: 3280 |  Loss: (0.0011) | Acc: (99.98%) (49205/49215)
# Epoch: 16 | Batch_idx: 3290 |  Loss: (0.0011) | Acc: (99.98%) (49355/49365)
# Epoch: 16 | Batch_idx: 3300 |  Loss: (0.0011) | Acc: (99.98%) (49505/49515)
# Epoch: 16 | Batch_idx: 3310 |  Loss: (0.0011) | Acc: (99.98%) (49655/49665)
# Epoch: 16 | Batch_idx: 3320 |  Loss: (0.0011) | Acc: (99.98%) (49805/49815)
# Epoch: 16 | Batch_idx: 3330 |  Loss: (0.0011) | Acc: (99.98%) (49955/49965)
# => saving checkpoint
# # TEST : Loss: (0.0914) | Acc: (97.85%) (9785/10000)
# Epoch: 17 | Batch_idx: 0 |  Loss: (0.0003) | Acc: (100.00%) (15/15)
# Epoch: 17 | Batch_idx: 10 |  Loss: (0.0030) | Acc: (100.00%) (165/165)
# Epoch: 17 | Batch_idx: 20 |  Loss: (0.0018) | Acc: (100.00%) (315/315)
# Epoch: 17 | Batch_idx: 30 |  Loss: (0.0014) | Acc: (100.00%) (465/465)
# Epoch: 17 | Batch_idx: 40 |  Loss: (0.0013) | Acc: (100.00%) (615/615)
# Epoch: 17 | Batch_idx: 50 |  Loss: (0.0011) | Acc: (100.00%) (765/765)
# Epoch: 17 | Batch_idx: 60 |  Loss: (0.0010) | Acc: (100.00%) (915/915)
# Epoch: 17 | Batch_idx: 70 |  Loss: (0.0009) | Acc: (100.00%) (1065/1065)
# Epoch: 17 | Batch_idx: 80 |  Loss: (0.0009) | Acc: (100.00%) (1215/1215)
# Epoch: 17 | Batch_idx: 90 |  Loss: (0.0008) | Acc: (100.00%) (1365/1365)
# Epoch: 17 | Batch_idx: 100 |  Loss: (0.0010) | Acc: (100.00%) (1515/1515)
# Epoch: 17 | Batch_idx: 110 |  Loss: (0.0010) | Acc: (100.00%) (1665/1665)
# Epoch: 17 | Batch_idx: 120 |  Loss: (0.0009) | Acc: (100.00%) (1815/1815)
# Epoch: 17 | Batch_idx: 130 |  Loss: (0.0009) | Acc: (100.00%) (1965/1965)
# Epoch: 17 | Batch_idx: 140 |  Loss: (0.0009) | Acc: (100.00%) (2115/2115)
# Epoch: 17 | Batch_idx: 150 |  Loss: (0.0008) | Acc: (100.00%) (2265/2265)
# Epoch: 17 | Batch_idx: 160 |  Loss: (0.0008) | Acc: (100.00%) (2415/2415)
# Epoch: 17 | Batch_idx: 170 |  Loss: (0.0008) | Acc: (100.00%) (2565/2565)
# Epoch: 17 | Batch_idx: 180 |  Loss: (0.0007) | Acc: (100.00%) (2715/2715)
# Epoch: 17 | Batch_idx: 190 |  Loss: (0.0007) | Acc: (100.00%) (2865/2865)
# Epoch: 17 | Batch_idx: 200 |  Loss: (0.0007) | Acc: (100.00%) (3015/3015)
# Epoch: 17 | Batch_idx: 210 |  Loss: (0.0007) | Acc: (100.00%) (3165/3165)
# Epoch: 17 | Batch_idx: 220 |  Loss: (0.0007) | Acc: (100.00%) (3315/3315)
# Epoch: 17 | Batch_idx: 230 |  Loss: (0.0007) | Acc: (100.00%) (3465/3465)
# Epoch: 17 | Batch_idx: 240 |  Loss: (0.0007) | Acc: (100.00%) (3615/3615)
# Epoch: 17 | Batch_idx: 250 |  Loss: (0.0007) | Acc: (100.00%) (3765/3765)
# Epoch: 17 | Batch_idx: 260 |  Loss: (0.0007) | Acc: (100.00%) (3915/3915)
# Epoch: 17 | Batch_idx: 270 |  Loss: (0.0007) | Acc: (100.00%) (4065/4065)
# Epoch: 17 | Batch_idx: 280 |  Loss: (0.0006) | Acc: (100.00%) (4215/4215)
# Epoch: 17 | Batch_idx: 290 |  Loss: (0.0006) | Acc: (100.00%) (4365/4365)
# Epoch: 17 | Batch_idx: 300 |  Loss: (0.0006) | Acc: (100.00%) (4515/4515)
# Epoch: 17 | Batch_idx: 310 |  Loss: (0.0006) | Acc: (100.00%) (4665/4665)
# Epoch: 17 | Batch_idx: 320 |  Loss: (0.0006) | Acc: (100.00%) (4815/4815)
# Epoch: 17 | Batch_idx: 330 |  Loss: (0.0006) | Acc: (100.00%) (4965/4965)
# Epoch: 17 | Batch_idx: 340 |  Loss: (0.0006) | Acc: (100.00%) (5115/5115)
# Epoch: 17 | Batch_idx: 350 |  Loss: (0.0006) | Acc: (100.00%) (5265/5265)
# Epoch: 17 | Batch_idx: 360 |  Loss: (0.0015) | Acc: (99.98%) (5414/5415)
# Epoch: 17 | Batch_idx: 370 |  Loss: (0.0015) | Acc: (99.98%) (5564/5565)
# Epoch: 17 | Batch_idx: 380 |  Loss: (0.0015) | Acc: (99.98%) (5714/5715)
# Epoch: 17 | Batch_idx: 390 |  Loss: (0.0015) | Acc: (99.98%) (5864/5865)
# Epoch: 17 | Batch_idx: 400 |  Loss: (0.0014) | Acc: (99.98%) (6014/6015)
# Epoch: 17 | Batch_idx: 410 |  Loss: (0.0014) | Acc: (99.98%) (6164/6165)
# Epoch: 17 | Batch_idx: 420 |  Loss: (0.0014) | Acc: (99.98%) (6314/6315)
# Epoch: 17 | Batch_idx: 430 |  Loss: (0.0014) | Acc: (99.98%) (6464/6465)
# Epoch: 17 | Batch_idx: 440 |  Loss: (0.0016) | Acc: (99.97%) (6613/6615)
# Epoch: 17 | Batch_idx: 450 |  Loss: (0.0015) | Acc: (99.97%) (6763/6765)
# Epoch: 17 | Batch_idx: 460 |  Loss: (0.0015) | Acc: (99.97%) (6913/6915)
# Epoch: 17 | Batch_idx: 470 |  Loss: (0.0015) | Acc: (99.97%) (7063/7065)
# Epoch: 17 | Batch_idx: 480 |  Loss: (0.0015) | Acc: (99.97%) (7213/7215)
# Epoch: 17 | Batch_idx: 490 |  Loss: (0.0014) | Acc: (99.97%) (7363/7365)
# Epoch: 17 | Batch_idx: 500 |  Loss: (0.0014) | Acc: (99.97%) (7513/7515)
# Epoch: 17 | Batch_idx: 510 |  Loss: (0.0014) | Acc: (99.97%) (7663/7665)
# Epoch: 17 | Batch_idx: 520 |  Loss: (0.0014) | Acc: (99.97%) (7813/7815)
# Epoch: 17 | Batch_idx: 530 |  Loss: (0.0014) | Acc: (99.97%) (7963/7965)
# Epoch: 17 | Batch_idx: 540 |  Loss: (0.0014) | Acc: (99.98%) (8113/8115)
# Epoch: 17 | Batch_idx: 550 |  Loss: (0.0014) | Acc: (99.98%) (8263/8265)
# Epoch: 17 | Batch_idx: 560 |  Loss: (0.0014) | Acc: (99.98%) (8413/8415)
# Epoch: 17 | Batch_idx: 570 |  Loss: (0.0014) | Acc: (99.98%) (8563/8565)
# Epoch: 17 | Batch_idx: 580 |  Loss: (0.0014) | Acc: (99.98%) (8713/8715)
# Epoch: 17 | Batch_idx: 590 |  Loss: (0.0014) | Acc: (99.98%) (8863/8865)
# Epoch: 17 | Batch_idx: 600 |  Loss: (0.0014) | Acc: (99.98%) (9013/9015)
# Epoch: 17 | Batch_idx: 610 |  Loss: (0.0013) | Acc: (99.98%) (9163/9165)
# Epoch: 17 | Batch_idx: 620 |  Loss: (0.0013) | Acc: (99.98%) (9313/9315)
# Epoch: 17 | Batch_idx: 630 |  Loss: (0.0013) | Acc: (99.98%) (9463/9465)
# Epoch: 17 | Batch_idx: 640 |  Loss: (0.0013) | Acc: (99.98%) (9613/9615)
# Epoch: 17 | Batch_idx: 650 |  Loss: (0.0013) | Acc: (99.98%) (9763/9765)
# Epoch: 17 | Batch_idx: 660 |  Loss: (0.0013) | Acc: (99.98%) (9913/9915)
# Epoch: 17 | Batch_idx: 670 |  Loss: (0.0013) | Acc: (99.98%) (10063/10065)
# Epoch: 17 | Batch_idx: 680 |  Loss: (0.0013) | Acc: (99.98%) (10213/10215)
# Epoch: 17 | Batch_idx: 690 |  Loss: (0.0013) | Acc: (99.98%) (10363/10365)
# Epoch: 17 | Batch_idx: 700 |  Loss: (0.0013) | Acc: (99.98%) (10513/10515)
# Epoch: 17 | Batch_idx: 710 |  Loss: (0.0012) | Acc: (99.98%) (10663/10665)
# Epoch: 17 | Batch_idx: 720 |  Loss: (0.0012) | Acc: (99.98%) (10813/10815)
# Epoch: 17 | Batch_idx: 730 |  Loss: (0.0012) | Acc: (99.98%) (10963/10965)
# Epoch: 17 | Batch_idx: 740 |  Loss: (0.0012) | Acc: (99.98%) (11113/11115)
# Epoch: 17 | Batch_idx: 750 |  Loss: (0.0012) | Acc: (99.98%) (11263/11265)
# Epoch: 17 | Batch_idx: 760 |  Loss: (0.0013) | Acc: (99.98%) (11413/11415)
# Epoch: 17 | Batch_idx: 770 |  Loss: (0.0013) | Acc: (99.98%) (11563/11565)
# Epoch: 17 | Batch_idx: 780 |  Loss: (0.0013) | Acc: (99.98%) (11713/11715)
# Epoch: 17 | Batch_idx: 790 |  Loss: (0.0013) | Acc: (99.98%) (11863/11865)
# Epoch: 17 | Batch_idx: 800 |  Loss: (0.0013) | Acc: (99.98%) (12013/12015)
# Epoch: 17 | Batch_idx: 810 |  Loss: (0.0013) | Acc: (99.98%) (12163/12165)
# Epoch: 17 | Batch_idx: 820 |  Loss: (0.0012) | Acc: (99.98%) (12313/12315)
# Epoch: 17 | Batch_idx: 830 |  Loss: (0.0012) | Acc: (99.98%) (12463/12465)
# Epoch: 17 | Batch_idx: 840 |  Loss: (0.0012) | Acc: (99.98%) (12613/12615)
# Epoch: 17 | Batch_idx: 850 |  Loss: (0.0012) | Acc: (99.98%) (12763/12765)
# Epoch: 17 | Batch_idx: 860 |  Loss: (0.0012) | Acc: (99.98%) (12913/12915)
# Epoch: 17 | Batch_idx: 870 |  Loss: (0.0012) | Acc: (99.98%) (13063/13065)
# Epoch: 17 | Batch_idx: 880 |  Loss: (0.0012) | Acc: (99.98%) (13213/13215)
# Epoch: 17 | Batch_idx: 890 |  Loss: (0.0012) | Acc: (99.99%) (13363/13365)
# Epoch: 17 | Batch_idx: 900 |  Loss: (0.0012) | Acc: (99.99%) (13513/13515)
# Epoch: 17 | Batch_idx: 910 |  Loss: (0.0012) | Acc: (99.99%) (13663/13665)
# Epoch: 17 | Batch_idx: 920 |  Loss: (0.0012) | Acc: (99.99%) (13813/13815)
# Epoch: 17 | Batch_idx: 930 |  Loss: (0.0012) | Acc: (99.99%) (13963/13965)
# Epoch: 17 | Batch_idx: 940 |  Loss: (0.0012) | Acc: (99.99%) (14113/14115)
# Epoch: 17 | Batch_idx: 950 |  Loss: (0.0012) | Acc: (99.99%) (14263/14265)
# Epoch: 17 | Batch_idx: 960 |  Loss: (0.0012) | Acc: (99.99%) (14413/14415)
# Epoch: 17 | Batch_idx: 970 |  Loss: (0.0012) | Acc: (99.99%) (14563/14565)
# Epoch: 17 | Batch_idx: 980 |  Loss: (0.0012) | Acc: (99.99%) (14713/14715)
# Epoch: 17 | Batch_idx: 990 |  Loss: (0.0012) | Acc: (99.99%) (14863/14865)
# Epoch: 17 | Batch_idx: 1000 |  Loss: (0.0012) | Acc: (99.99%) (15013/15015)
# Epoch: 17 | Batch_idx: 1010 |  Loss: (0.0012) | Acc: (99.99%) (15163/15165)
# Epoch: 17 | Batch_idx: 1020 |  Loss: (0.0012) | Acc: (99.99%) (15313/15315)
# Epoch: 17 | Batch_idx: 1030 |  Loss: (0.0012) | Acc: (99.99%) (15463/15465)
# Epoch: 17 | Batch_idx: 1040 |  Loss: (0.0012) | Acc: (99.99%) (15613/15615)
# Epoch: 17 | Batch_idx: 1050 |  Loss: (0.0012) | Acc: (99.99%) (15763/15765)
# Epoch: 17 | Batch_idx: 1060 |  Loss: (0.0012) | Acc: (99.99%) (15913/15915)
# Epoch: 17 | Batch_idx: 1070 |  Loss: (0.0012) | Acc: (99.99%) (16063/16065)
# Epoch: 17 | Batch_idx: 1080 |  Loss: (0.0012) | Acc: (99.99%) (16213/16215)
# Epoch: 17 | Batch_idx: 1090 |  Loss: (0.0012) | Acc: (99.99%) (16363/16365)
# Epoch: 17 | Batch_idx: 1100 |  Loss: (0.0012) | Acc: (99.99%) (16513/16515)
# Epoch: 17 | Batch_idx: 1110 |  Loss: (0.0012) | Acc: (99.99%) (16663/16665)
# Epoch: 17 | Batch_idx: 1120 |  Loss: (0.0012) | Acc: (99.99%) (16813/16815)
# Epoch: 17 | Batch_idx: 1130 |  Loss: (0.0012) | Acc: (99.99%) (16963/16965)
# Epoch: 17 | Batch_idx: 1140 |  Loss: (0.0012) | Acc: (99.99%) (17113/17115)
# Epoch: 17 | Batch_idx: 1150 |  Loss: (0.0012) | Acc: (99.99%) (17263/17265)
# Epoch: 17 | Batch_idx: 1160 |  Loss: (0.0012) | Acc: (99.99%) (17413/17415)
# Epoch: 17 | Batch_idx: 1170 |  Loss: (0.0012) | Acc: (99.99%) (17563/17565)
# Epoch: 17 | Batch_idx: 1180 |  Loss: (0.0012) | Acc: (99.99%) (17713/17715)
# Epoch: 17 | Batch_idx: 1190 |  Loss: (0.0012) | Acc: (99.99%) (17863/17865)
# Epoch: 17 | Batch_idx: 1200 |  Loss: (0.0012) | Acc: (99.99%) (18013/18015)
# Epoch: 17 | Batch_idx: 1210 |  Loss: (0.0012) | Acc: (99.99%) (18163/18165)
# Epoch: 17 | Batch_idx: 1220 |  Loss: (0.0012) | Acc: (99.99%) (18313/18315)
# Epoch: 17 | Batch_idx: 1230 |  Loss: (0.0012) | Acc: (99.99%) (18463/18465)
# Epoch: 17 | Batch_idx: 1240 |  Loss: (0.0012) | Acc: (99.99%) (18613/18615)
# Epoch: 17 | Batch_idx: 1250 |  Loss: (0.0012) | Acc: (99.99%) (18763/18765)
# Epoch: 17 | Batch_idx: 1260 |  Loss: (0.0012) | Acc: (99.99%) (18913/18915)
# Epoch: 17 | Batch_idx: 1270 |  Loss: (0.0012) | Acc: (99.99%) (19063/19065)
# Epoch: 17 | Batch_idx: 1280 |  Loss: (0.0012) | Acc: (99.99%) (19213/19215)
# Epoch: 17 | Batch_idx: 1290 |  Loss: (0.0012) | Acc: (99.99%) (19363/19365)
# Epoch: 17 | Batch_idx: 1300 |  Loss: (0.0012) | Acc: (99.99%) (19513/19515)
# Epoch: 17 | Batch_idx: 1310 |  Loss: (0.0012) | Acc: (99.99%) (19663/19665)
# Epoch: 17 | Batch_idx: 1320 |  Loss: (0.0011) | Acc: (99.99%) (19813/19815)
# Epoch: 17 | Batch_idx: 1330 |  Loss: (0.0011) | Acc: (99.99%) (19963/19965)
# Epoch: 17 | Batch_idx: 1340 |  Loss: (0.0012) | Acc: (99.99%) (20113/20115)
# Epoch: 17 | Batch_idx: 1350 |  Loss: (0.0012) | Acc: (99.99%) (20263/20265)
# Epoch: 17 | Batch_idx: 1360 |  Loss: (0.0011) | Acc: (99.99%) (20413/20415)
# Epoch: 17 | Batch_idx: 1370 |  Loss: (0.0011) | Acc: (99.99%) (20563/20565)
# Epoch: 17 | Batch_idx: 1380 |  Loss: (0.0011) | Acc: (99.99%) (20713/20715)
# Epoch: 17 | Batch_idx: 1390 |  Loss: (0.0011) | Acc: (99.99%) (20863/20865)
# Epoch: 17 | Batch_idx: 1400 |  Loss: (0.0011) | Acc: (99.99%) (21013/21015)
# Epoch: 17 | Batch_idx: 1410 |  Loss: (0.0011) | Acc: (99.99%) (21163/21165)
# Epoch: 17 | Batch_idx: 1420 |  Loss: (0.0012) | Acc: (99.99%) (21313/21315)
# Epoch: 17 | Batch_idx: 1430 |  Loss: (0.0011) | Acc: (99.99%) (21463/21465)
# Epoch: 17 | Batch_idx: 1440 |  Loss: (0.0012) | Acc: (99.99%) (21613/21615)
# Epoch: 17 | Batch_idx: 1450 |  Loss: (0.0012) | Acc: (99.99%) (21763/21765)
# Epoch: 17 | Batch_idx: 1460 |  Loss: (0.0012) | Acc: (99.99%) (21913/21915)
# Epoch: 17 | Batch_idx: 1470 |  Loss: (0.0012) | Acc: (99.99%) (22063/22065)
# Epoch: 17 | Batch_idx: 1480 |  Loss: (0.0011) | Acc: (99.99%) (22213/22215)
# Epoch: 17 | Batch_idx: 1490 |  Loss: (0.0013) | Acc: (99.98%) (22361/22365)
# Epoch: 17 | Batch_idx: 1500 |  Loss: (0.0013) | Acc: (99.98%) (22511/22515)
# Epoch: 17 | Batch_idx: 1510 |  Loss: (0.0012) | Acc: (99.98%) (22661/22665)
# Epoch: 17 | Batch_idx: 1520 |  Loss: (0.0012) | Acc: (99.98%) (22811/22815)
# Epoch: 17 | Batch_idx: 1530 |  Loss: (0.0012) | Acc: (99.98%) (22961/22965)
# Epoch: 17 | Batch_idx: 1540 |  Loss: (0.0012) | Acc: (99.98%) (23111/23115)
# Epoch: 17 | Batch_idx: 1550 |  Loss: (0.0012) | Acc: (99.98%) (23261/23265)
# Epoch: 17 | Batch_idx: 1560 |  Loss: (0.0014) | Acc: (99.98%) (23410/23415)
# Epoch: 17 | Batch_idx: 1570 |  Loss: (0.0014) | Acc: (99.98%) (23560/23565)
# Epoch: 17 | Batch_idx: 1580 |  Loss: (0.0014) | Acc: (99.98%) (23710/23715)
# Epoch: 17 | Batch_idx: 1590 |  Loss: (0.0014) | Acc: (99.98%) (23860/23865)
# Epoch: 17 | Batch_idx: 1600 |  Loss: (0.0014) | Acc: (99.98%) (24010/24015)
# Epoch: 17 | Batch_idx: 1610 |  Loss: (0.0014) | Acc: (99.98%) (24160/24165)
# Epoch: 17 | Batch_idx: 1620 |  Loss: (0.0014) | Acc: (99.98%) (24310/24315)
# Epoch: 17 | Batch_idx: 1630 |  Loss: (0.0014) | Acc: (99.98%) (24460/24465)
# Epoch: 17 | Batch_idx: 1640 |  Loss: (0.0013) | Acc: (99.98%) (24610/24615)
# Epoch: 17 | Batch_idx: 1650 |  Loss: (0.0013) | Acc: (99.98%) (24760/24765)
# Epoch: 17 | Batch_idx: 1660 |  Loss: (0.0013) | Acc: (99.98%) (24910/24915)
# Epoch: 17 | Batch_idx: 1670 |  Loss: (0.0013) | Acc: (99.98%) (25060/25065)
# Epoch: 17 | Batch_idx: 1680 |  Loss: (0.0014) | Acc: (99.98%) (25210/25215)
# Epoch: 17 | Batch_idx: 1690 |  Loss: (0.0013) | Acc: (99.98%) (25360/25365)
# Epoch: 17 | Batch_idx: 1700 |  Loss: (0.0013) | Acc: (99.98%) (25510/25515)
# Epoch: 17 | Batch_idx: 1710 |  Loss: (0.0013) | Acc: (99.98%) (25660/25665)
# Epoch: 17 | Batch_idx: 1720 |  Loss: (0.0013) | Acc: (99.98%) (25810/25815)
# Epoch: 17 | Batch_idx: 1730 |  Loss: (0.0013) | Acc: (99.98%) (25960/25965)
# Epoch: 17 | Batch_idx: 1740 |  Loss: (0.0013) | Acc: (99.98%) (26110/26115)
# Epoch: 17 | Batch_idx: 1750 |  Loss: (0.0014) | Acc: (99.98%) (26259/26265)
# Epoch: 17 | Batch_idx: 1760 |  Loss: (0.0014) | Acc: (99.98%) (26409/26415)
# Epoch: 17 | Batch_idx: 1770 |  Loss: (0.0013) | Acc: (99.98%) (26559/26565)
# Epoch: 17 | Batch_idx: 1780 |  Loss: (0.0013) | Acc: (99.98%) (26709/26715)
# Epoch: 17 | Batch_idx: 1790 |  Loss: (0.0013) | Acc: (99.98%) (26859/26865)
# Epoch: 17 | Batch_idx: 1800 |  Loss: (0.0013) | Acc: (99.98%) (27009/27015)
# Epoch: 17 | Batch_idx: 1810 |  Loss: (0.0013) | Acc: (99.98%) (27159/27165)
# Epoch: 17 | Batch_idx: 1820 |  Loss: (0.0013) | Acc: (99.98%) (27309/27315)
# Epoch: 17 | Batch_idx: 1830 |  Loss: (0.0013) | Acc: (99.98%) (27459/27465)
# Epoch: 17 | Batch_idx: 1840 |  Loss: (0.0013) | Acc: (99.98%) (27609/27615)
# Epoch: 17 | Batch_idx: 1850 |  Loss: (0.0013) | Acc: (99.98%) (27759/27765)
# Epoch: 17 | Batch_idx: 1860 |  Loss: (0.0013) | Acc: (99.98%) (27909/27915)
# Epoch: 17 | Batch_idx: 1870 |  Loss: (0.0013) | Acc: (99.98%) (28059/28065)
# Epoch: 17 | Batch_idx: 1880 |  Loss: (0.0013) | Acc: (99.98%) (28209/28215)
# Epoch: 17 | Batch_idx: 1890 |  Loss: (0.0013) | Acc: (99.98%) (28359/28365)
# Epoch: 17 | Batch_idx: 1900 |  Loss: (0.0013) | Acc: (99.98%) (28509/28515)
# Epoch: 17 | Batch_idx: 1910 |  Loss: (0.0013) | Acc: (99.98%) (28659/28665)
# Epoch: 17 | Batch_idx: 1920 |  Loss: (0.0013) | Acc: (99.98%) (28809/28815)
# Epoch: 17 | Batch_idx: 1930 |  Loss: (0.0013) | Acc: (99.98%) (28959/28965)
# Epoch: 17 | Batch_idx: 1940 |  Loss: (0.0013) | Acc: (99.98%) (29109/29115)
# Epoch: 17 | Batch_idx: 1950 |  Loss: (0.0013) | Acc: (99.98%) (29259/29265)
# Epoch: 17 | Batch_idx: 1960 |  Loss: (0.0013) | Acc: (99.98%) (29409/29415)
# Epoch: 17 | Batch_idx: 1970 |  Loss: (0.0013) | Acc: (99.98%) (29559/29565)
# Epoch: 17 | Batch_idx: 1980 |  Loss: (0.0013) | Acc: (99.98%) (29709/29715)
# Epoch: 17 | Batch_idx: 1990 |  Loss: (0.0013) | Acc: (99.98%) (29859/29865)
# Epoch: 17 | Batch_idx: 2000 |  Loss: (0.0013) | Acc: (99.98%) (30008/30015)
# Epoch: 17 | Batch_idx: 2010 |  Loss: (0.0013) | Acc: (99.98%) (30158/30165)
# Epoch: 17 | Batch_idx: 2020 |  Loss: (0.0013) | Acc: (99.98%) (30308/30315)
# Epoch: 17 | Batch_idx: 2030 |  Loss: (0.0013) | Acc: (99.98%) (30458/30465)
# Epoch: 17 | Batch_idx: 2040 |  Loss: (0.0013) | Acc: (99.98%) (30608/30615)
# Epoch: 17 | Batch_idx: 2050 |  Loss: (0.0013) | Acc: (99.98%) (30758/30765)
# Epoch: 17 | Batch_idx: 2060 |  Loss: (0.0013) | Acc: (99.98%) (30908/30915)
# Epoch: 17 | Batch_idx: 2070 |  Loss: (0.0013) | Acc: (99.98%) (31058/31065)
# Epoch: 17 | Batch_idx: 2080 |  Loss: (0.0013) | Acc: (99.98%) (31208/31215)
# Epoch: 17 | Batch_idx: 2090 |  Loss: (0.0013) | Acc: (99.98%) (31358/31365)
# Epoch: 17 | Batch_idx: 2100 |  Loss: (0.0012) | Acc: (99.98%) (31508/31515)
# Epoch: 17 | Batch_idx: 2110 |  Loss: (0.0012) | Acc: (99.98%) (31658/31665)
# Epoch: 17 | Batch_idx: 2120 |  Loss: (0.0012) | Acc: (99.98%) (31808/31815)
# Epoch: 17 | Batch_idx: 2130 |  Loss: (0.0012) | Acc: (99.98%) (31958/31965)
# Epoch: 17 | Batch_idx: 2140 |  Loss: (0.0012) | Acc: (99.98%) (32108/32115)
# Epoch: 17 | Batch_idx: 2150 |  Loss: (0.0012) | Acc: (99.98%) (32258/32265)
# Epoch: 17 | Batch_idx: 2160 |  Loss: (0.0012) | Acc: (99.98%) (32408/32415)
# Epoch: 17 | Batch_idx: 2170 |  Loss: (0.0012) | Acc: (99.98%) (32558/32565)
# Epoch: 17 | Batch_idx: 2180 |  Loss: (0.0012) | Acc: (99.98%) (32708/32715)
# Epoch: 17 | Batch_idx: 2190 |  Loss: (0.0012) | Acc: (99.98%) (32858/32865)
# Epoch: 17 | Batch_idx: 2200 |  Loss: (0.0012) | Acc: (99.98%) (33008/33015)
# Epoch: 17 | Batch_idx: 2210 |  Loss: (0.0012) | Acc: (99.98%) (33158/33165)
# Epoch: 17 | Batch_idx: 2220 |  Loss: (0.0012) | Acc: (99.98%) (33308/33315)
# Epoch: 17 | Batch_idx: 2230 |  Loss: (0.0012) | Acc: (99.98%) (33458/33465)
# Epoch: 17 | Batch_idx: 2240 |  Loss: (0.0012) | Acc: (99.98%) (33608/33615)
# Epoch: 17 | Batch_idx: 2250 |  Loss: (0.0012) | Acc: (99.98%) (33758/33765)
# Epoch: 17 | Batch_idx: 2260 |  Loss: (0.0012) | Acc: (99.98%) (33908/33915)
# Epoch: 17 | Batch_idx: 2270 |  Loss: (0.0012) | Acc: (99.98%) (34058/34065)
# Epoch: 17 | Batch_idx: 2280 |  Loss: (0.0012) | Acc: (99.98%) (34208/34215)
# Epoch: 17 | Batch_idx: 2290 |  Loss: (0.0012) | Acc: (99.98%) (34358/34365)
# Epoch: 17 | Batch_idx: 2300 |  Loss: (0.0012) | Acc: (99.98%) (34508/34515)
# Epoch: 17 | Batch_idx: 2310 |  Loss: (0.0012) | Acc: (99.98%) (34658/34665)
# Epoch: 17 | Batch_idx: 2320 |  Loss: (0.0012) | Acc: (99.98%) (34808/34815)
# Epoch: 17 | Batch_idx: 2330 |  Loss: (0.0012) | Acc: (99.98%) (34958/34965)
# Epoch: 17 | Batch_idx: 2340 |  Loss: (0.0012) | Acc: (99.98%) (35108/35115)
# Epoch: 17 | Batch_idx: 2350 |  Loss: (0.0012) | Acc: (99.98%) (35258/35265)
# Epoch: 17 | Batch_idx: 2360 |  Loss: (0.0012) | Acc: (99.98%) (35408/35415)
# Epoch: 17 | Batch_idx: 2370 |  Loss: (0.0012) | Acc: (99.98%) (35558/35565)
# Epoch: 17 | Batch_idx: 2380 |  Loss: (0.0012) | Acc: (99.98%) (35708/35715)
# Epoch: 17 | Batch_idx: 2390 |  Loss: (0.0012) | Acc: (99.98%) (35858/35865)
# Epoch: 17 | Batch_idx: 2400 |  Loss: (0.0012) | Acc: (99.98%) (36008/36015)
# Epoch: 17 | Batch_idx: 2410 |  Loss: (0.0012) | Acc: (99.98%) (36158/36165)
# Epoch: 17 | Batch_idx: 2420 |  Loss: (0.0012) | Acc: (99.98%) (36308/36315)
# Epoch: 17 | Batch_idx: 2430 |  Loss: (0.0012) | Acc: (99.98%) (36458/36465)
# Epoch: 17 | Batch_idx: 2440 |  Loss: (0.0012) | Acc: (99.98%) (36608/36615)
# Epoch: 17 | Batch_idx: 2450 |  Loss: (0.0012) | Acc: (99.98%) (36758/36765)
# Epoch: 17 | Batch_idx: 2460 |  Loss: (0.0012) | Acc: (99.98%) (36908/36915)
# Epoch: 17 | Batch_idx: 2470 |  Loss: (0.0012) | Acc: (99.98%) (37058/37065)
# Epoch: 17 | Batch_idx: 2480 |  Loss: (0.0012) | Acc: (99.98%) (37208/37215)
# Epoch: 17 | Batch_idx: 2490 |  Loss: (0.0012) | Acc: (99.98%) (37358/37365)
# Epoch: 17 | Batch_idx: 2500 |  Loss: (0.0011) | Acc: (99.98%) (37508/37515)
# Epoch: 17 | Batch_idx: 2510 |  Loss: (0.0011) | Acc: (99.98%) (37658/37665)
# Epoch: 17 | Batch_idx: 2520 |  Loss: (0.0011) | Acc: (99.98%) (37808/37815)
# Epoch: 17 | Batch_idx: 2530 |  Loss: (0.0011) | Acc: (99.98%) (37958/37965)
# Epoch: 17 | Batch_idx: 2540 |  Loss: (0.0011) | Acc: (99.98%) (38108/38115)
# Epoch: 17 | Batch_idx: 2550 |  Loss: (0.0011) | Acc: (99.98%) (38258/38265)
# Epoch: 17 | Batch_idx: 2560 |  Loss: (0.0011) | Acc: (99.98%) (38408/38415)
# Epoch: 17 | Batch_idx: 2570 |  Loss: (0.0011) | Acc: (99.98%) (38558/38565)
# Epoch: 17 | Batch_idx: 2580 |  Loss: (0.0011) | Acc: (99.98%) (38708/38715)
# Epoch: 17 | Batch_idx: 2590 |  Loss: (0.0011) | Acc: (99.98%) (38858/38865)
# Epoch: 17 | Batch_idx: 2600 |  Loss: (0.0011) | Acc: (99.98%) (39008/39015)
# Epoch: 17 | Batch_idx: 2610 |  Loss: (0.0011) | Acc: (99.98%) (39158/39165)
# Epoch: 17 | Batch_idx: 2620 |  Loss: (0.0011) | Acc: (99.98%) (39308/39315)
# Epoch: 17 | Batch_idx: 2630 |  Loss: (0.0011) | Acc: (99.98%) (39458/39465)
# Epoch: 17 | Batch_idx: 2640 |  Loss: (0.0011) | Acc: (99.98%) (39608/39615)
# Epoch: 17 | Batch_idx: 2650 |  Loss: (0.0011) | Acc: (99.98%) (39758/39765)
# Epoch: 17 | Batch_idx: 2660 |  Loss: (0.0011) | Acc: (99.98%) (39908/39915)
# Epoch: 17 | Batch_idx: 2670 |  Loss: (0.0011) | Acc: (99.98%) (40058/40065)
# Epoch: 17 | Batch_idx: 2680 |  Loss: (0.0011) | Acc: (99.98%) (40208/40215)
# Epoch: 17 | Batch_idx: 2690 |  Loss: (0.0011) | Acc: (99.98%) (40358/40365)
# Epoch: 17 | Batch_idx: 2700 |  Loss: (0.0011) | Acc: (99.98%) (40508/40515)
# Epoch: 17 | Batch_idx: 2710 |  Loss: (0.0011) | Acc: (99.98%) (40658/40665)
# Epoch: 17 | Batch_idx: 2720 |  Loss: (0.0011) | Acc: (99.98%) (40808/40815)
# Epoch: 17 | Batch_idx: 2730 |  Loss: (0.0011) | Acc: (99.98%) (40958/40965)
# Epoch: 17 | Batch_idx: 2740 |  Loss: (0.0011) | Acc: (99.98%) (41108/41115)
# Epoch: 17 | Batch_idx: 2750 |  Loss: (0.0011) | Acc: (99.98%) (41258/41265)
# Epoch: 17 | Batch_idx: 2760 |  Loss: (0.0011) | Acc: (99.98%) (41408/41415)
# Epoch: 17 | Batch_idx: 2770 |  Loss: (0.0011) | Acc: (99.98%) (41558/41565)
# ...
# Epoch: 19 | Batch_idx: 1280 |  Loss: (0.0008) | Acc: (99.98%) (19212/19215)
# Epoch: 19 | Batch_idx: 1290 |  Loss: (0.0008) | Acc: (99.98%) (19362/19365)
# Epoch: 19 | Batch_idx: 1300 |  Loss: (0.0008) | Acc: (99.98%) (19512/19515)
# Epoch: 19 | Batch_idx: 1310 |  Loss: (0.0008) | Acc: (99.98%) (19662/19665)
# Epoch: 19 | Batch_idx: 1320 |  Loss: (0.0008) | Acc: (99.98%) (19812/19815)
# Epoch: 19 | Batch_idx: 1330 |  Loss: (0.0008) | Acc: (99.98%) (19962/19965)
# Epoch: 19 | Batch_idx: 1340 |  Loss: (0.0008) | Acc: (99.99%) (20112/20115)
# Epoch: 19 | Batch_idx: 1350 |  Loss: (0.0008) | Acc: (99.99%) (20262/20265)
# Epoch: 19 | Batch_idx: 1360 |  Loss: (0.0008) | Acc: (99.99%) (20412/20415)
# Epoch: 19 | Batch_idx: 1370 |  Loss: (0.0008) | Acc: (99.99%) (20562/20565)
# Epoch: 19 | Batch_idx: 1380 |  Loss: (0.0008) | Acc: (99.99%) (20712/20715)
# Epoch: 19 | Batch_idx: 1390 |  Loss: (0.0008) | Acc: (99.99%) (20862/20865)
# Epoch: 19 | Batch_idx: 1400 |  Loss: (0.0008) | Acc: (99.99%) (21012/21015)
# Epoch: 19 | Batch_idx: 1410 |  Loss: (0.0008) | Acc: (99.99%) (21162/21165)
# Epoch: 19 | Batch_idx: 1420 |  Loss: (0.0008) | Acc: (99.99%) (21312/21315)
# Epoch: 19 | Batch_idx: 1430 |  Loss: (0.0008) | Acc: (99.99%) (21462/21465)
# Epoch: 19 | Batch_idx: 1440 |  Loss: (0.0008) | Acc: (99.99%) (21612/21615)
# Epoch: 19 | Batch_idx: 1450 |  Loss: (0.0008) | Acc: (99.98%) (21761/21765)
# Epoch: 19 | Batch_idx: 1460 |  Loss: (0.0008) | Acc: (99.98%) (21911/21915)
# Epoch: 19 | Batch_idx: 1470 |  Loss: (0.0008) | Acc: (99.98%) (22061/22065)
# Epoch: 19 | Batch_idx: 1480 |  Loss: (0.0008) | Acc: (99.98%) (22211/22215)
# Epoch: 19 | Batch_idx: 1490 |  Loss: (0.0008) | Acc: (99.98%) (22361/22365)
# Epoch: 19 | Batch_idx: 1500 |  Loss: (0.0008) | Acc: (99.98%) (22511/22515)
# Epoch: 19 | Batch_idx: 1510 |  Loss: (0.0008) | Acc: (99.98%) (22661/22665)
# Epoch: 19 | Batch_idx: 1520 |  Loss: (0.0008) | Acc: (99.98%) (22811/22815)
# Epoch: 19 | Batch_idx: 1530 |  Loss: (0.0008) | Acc: (99.98%) (22961/22965)
# Epoch: 19 | Batch_idx: 1540 |  Loss: (0.0008) | Acc: (99.98%) (23111/23115)
# Epoch: 19 | Batch_idx: 1550 |  Loss: (0.0008) | Acc: (99.98%) (23261/23265)
# Epoch: 19 | Batch_idx: 1560 |  Loss: (0.0008) | Acc: (99.98%) (23411/23415)
# Epoch: 19 | Batch_idx: 1570 |  Loss: (0.0008) | Acc: (99.98%) (23561/23565)
# Epoch: 19 | Batch_idx: 1580 |  Loss: (0.0008) | Acc: (99.98%) (23711/23715)
# Epoch: 19 | Batch_idx: 1590 |  Loss: (0.0008) | Acc: (99.98%) (23861/23865)
# Epoch: 19 | Batch_idx: 1600 |  Loss: (0.0008) | Acc: (99.98%) (24011/24015)
# Epoch: 19 | Batch_idx: 1610 |  Loss: (0.0008) | Acc: (99.98%) (24161/24165)
# Epoch: 19 | Batch_idx: 1620 |  Loss: (0.0008) | Acc: (99.98%) (24311/24315)
# Epoch: 19 | Batch_idx: 1630 |  Loss: (0.0008) | Acc: (99.98%) (24461/24465)
# Epoch: 19 | Batch_idx: 1640 |  Loss: (0.0009) | Acc: (99.98%) (24611/24615)
# Epoch: 19 | Batch_idx: 1650 |  Loss: (0.0009) | Acc: (99.98%) (24761/24765)
# Epoch: 19 | Batch_idx: 1660 |  Loss: (0.0009) | Acc: (99.98%) (24911/24915)
# Epoch: 19 | Batch_idx: 1670 |  Loss: (0.0009) | Acc: (99.98%) (25061/25065)
# Epoch: 19 | Batch_idx: 1680 |  Loss: (0.0008) | Acc: (99.98%) (25211/25215)
# Epoch: 19 | Batch_idx: 1690 |  Loss: (0.0010) | Acc: (99.98%) (25360/25365)
# Epoch: 19 | Batch_idx: 1700 |  Loss: (0.0010) | Acc: (99.98%) (25510/25515)
# Epoch: 19 | Batch_idx: 1710 |  Loss: (0.0010) | Acc: (99.98%) (25660/25665)
# Epoch: 19 | Batch_idx: 1720 |  Loss: (0.0010) | Acc: (99.98%) (25810/25815)
# Epoch: 19 | Batch_idx: 1730 |  Loss: (0.0010) | Acc: (99.98%) (25960/25965)
# Epoch: 19 | Batch_idx: 1740 |  Loss: (0.0010) | Acc: (99.98%) (26110/26115)
# Epoch: 19 | Batch_idx: 1750 |  Loss: (0.0010) | Acc: (99.98%) (26260/26265)
# Epoch: 19 | Batch_idx: 1760 |  Loss: (0.0010) | Acc: (99.98%) (26410/26415)
# Epoch: 19 | Batch_idx: 1770 |  Loss: (0.0010) | Acc: (99.98%) (26560/26565)
# Epoch: 19 | Batch_idx: 1780 |  Loss: (0.0010) | Acc: (99.98%) (26710/26715)
# Epoch: 19 | Batch_idx: 1790 |  Loss: (0.0010) | Acc: (99.98%) (26860/26865)
# Epoch: 19 | Batch_idx: 1800 |  Loss: (0.0010) | Acc: (99.98%) (27010/27015)
# Epoch: 19 | Batch_idx: 1810 |  Loss: (0.0010) | Acc: (99.98%) (27160/27165)
# Epoch: 19 | Batch_idx: 1820 |  Loss: (0.0010) | Acc: (99.98%) (27310/27315)
# Epoch: 19 | Batch_idx: 1830 |  Loss: (0.0010) | Acc: (99.98%) (27460/27465)
# Epoch: 19 | Batch_idx: 1840 |  Loss: (0.0010) | Acc: (99.98%) (27610/27615)
# Epoch: 19 | Batch_idx: 1850 |  Loss: (0.0010) | Acc: (99.98%) (27760/27765)
# Epoch: 19 | Batch_idx: 1860 |  Loss: (0.0010) | Acc: (99.98%) (27910/27915)
# Epoch: 19 | Batch_idx: 1870 |  Loss: (0.0010) | Acc: (99.98%) (28060/28065)
# Epoch: 19 | Batch_idx: 1880 |  Loss: (0.0010) | Acc: (99.98%) (28210/28215)
# Epoch: 19 | Batch_idx: 1890 |  Loss: (0.0010) | Acc: (99.98%) (28360/28365)
# Epoch: 19 | Batch_idx: 1900 |  Loss: (0.0010) | Acc: (99.98%) (28510/28515)
# Epoch: 19 | Batch_idx: 1910 |  Loss: (0.0010) | Acc: (99.98%) (28660/28665)
# Epoch: 19 | Batch_idx: 1920 |  Loss: (0.0009) | Acc: (99.98%) (28810/28815)
# Epoch: 19 | Batch_idx: 1930 |  Loss: (0.0010) | Acc: (99.98%) (28960/28965)
# Epoch: 19 | Batch_idx: 1940 |  Loss: (0.0010) | Acc: (99.98%) (29110/29115)
# Epoch: 19 | Batch_idx: 1950 |  Loss: (0.0010) | Acc: (99.98%) (29260/29265)
# Epoch: 19 | Batch_idx: 1960 |  Loss: (0.0010) | Acc: (99.98%) (29410/29415)
# Epoch: 19 | Batch_idx: 1970 |  Loss: (0.0010) | Acc: (99.98%) (29560/29565)
# Epoch: 19 | Batch_idx: 1980 |  Loss: (0.0009) | Acc: (99.98%) (29710/29715)
# Epoch: 19 | Batch_idx: 1990 |  Loss: (0.0009) | Acc: (99.98%) (29860/29865)
# Epoch: 19 | Batch_idx: 2000 |  Loss: (0.0009) | Acc: (99.98%) (30010/30015)
# Epoch: 19 | Batch_idx: 2010 |  Loss: (0.0009) | Acc: (99.98%) (30160/30165)
# Epoch: 19 | Batch_idx: 2020 |  Loss: (0.0009) | Acc: (99.98%) (30310/30315)
# Epoch: 19 | Batch_idx: 2030 |  Loss: (0.0009) | Acc: (99.98%) (30460/30465)
# Epoch: 19 | Batch_idx: 2040 |  Loss: (0.0009) | Acc: (99.98%) (30610/30615)
# Epoch: 19 | Batch_idx: 2050 |  Loss: (0.0009) | Acc: (99.98%) (30760/30765)
# Epoch: 19 | Batch_idx: 2060 |  Loss: (0.0009) | Acc: (99.98%) (30910/30915)
# Epoch: 19 | Batch_idx: 2070 |  Loss: (0.0009) | Acc: (99.98%) (31060/31065)
# Epoch: 19 | Batch_idx: 2080 |  Loss: (0.0009) | Acc: (99.98%) (31210/31215)
# Epoch: 19 | Batch_idx: 2090 |  Loss: (0.0009) | Acc: (99.98%) (31360/31365)
# Epoch: 19 | Batch_idx: 2100 |  Loss: (0.0009) | Acc: (99.98%) (31510/31515)
# Epoch: 19 | Batch_idx: 2110 |  Loss: (0.0009) | Acc: (99.98%) (31660/31665)
# Epoch: 19 | Batch_idx: 2120 |  Loss: (0.0009) | Acc: (99.98%) (31810/31815)
# Epoch: 19 | Batch_idx: 2130 |  Loss: (0.0009) | Acc: (99.98%) (31960/31965)
# Epoch: 19 | Batch_idx: 2140 |  Loss: (0.0009) | Acc: (99.98%) (32110/32115)
# Epoch: 19 | Batch_idx: 2150 |  Loss: (0.0009) | Acc: (99.98%) (32260/32265)
# Epoch: 19 | Batch_idx: 2160 |  Loss: (0.0009) | Acc: (99.98%) (32410/32415)
# Epoch: 19 | Batch_idx: 2170 |  Loss: (0.0009) | Acc: (99.98%) (32560/32565)
# Epoch: 19 | Batch_idx: 2180 |  Loss: (0.0009) | Acc: (99.98%) (32710/32715)
# Epoch: 19 | Batch_idx: 2190 |  Loss: (0.0009) | Acc: (99.98%) (32860/32865)
# Epoch: 19 | Batch_idx: 2200 |  Loss: (0.0009) | Acc: (99.98%) (33010/33015)
# Epoch: 19 | Batch_idx: 2210 |  Loss: (0.0009) | Acc: (99.98%) (33160/33165)
# Epoch: 19 | Batch_idx: 2220 |  Loss: (0.0009) | Acc: (99.98%) (33310/33315)
# Epoch: 19 | Batch_idx: 2230 |  Loss: (0.0009) | Acc: (99.99%) (33460/33465)
# Epoch: 19 | Batch_idx: 2240 |  Loss: (0.0009) | Acc: (99.99%) (33610/33615)
# Epoch: 19 | Batch_idx: 2250 |  Loss: (0.0009) | Acc: (99.99%) (33760/33765)
# Epoch: 19 | Batch_idx: 2260 |  Loss: (0.0009) | Acc: (99.99%) (33910/33915)
# Epoch: 19 | Batch_idx: 2270 |  Loss: (0.0009) | Acc: (99.99%) (34060/34065)
# Epoch: 19 | Batch_idx: 2280 |  Loss: (0.0009) | Acc: (99.99%) (34210/34215)
# Epoch: 19 | Batch_idx: 2290 |  Loss: (0.0009) | Acc: (99.99%) (34360/34365)
# Epoch: 19 | Batch_idx: 2300 |  Loss: (0.0009) | Acc: (99.99%) (34510/34515)
# Epoch: 19 | Batch_idx: 2310 |  Loss: (0.0009) | Acc: (99.99%) (34660/34665)
# Epoch: 19 | Batch_idx: 2320 |  Loss: (0.0009) | Acc: (99.99%) (34810/34815)
# Epoch: 19 | Batch_idx: 2330 |  Loss: (0.0009) | Acc: (99.99%) (34960/34965)
# Epoch: 19 | Batch_idx: 2340 |  Loss: (0.0009) | Acc: (99.99%) (35110/35115)
# Epoch: 19 | Batch_idx: 2350 |  Loss: (0.0009) | Acc: (99.99%) (35260/35265)
# Epoch: 19 | Batch_idx: 2360 |  Loss: (0.0009) | Acc: (99.99%) (35410/35415)
# Epoch: 19 | Batch_idx: 2370 |  Loss: (0.0009) | Acc: (99.99%) (35560/35565)
# Epoch: 19 | Batch_idx: 2380 |  Loss: (0.0009) | Acc: (99.99%) (35710/35715)
# Epoch: 19 | Batch_idx: 2390 |  Loss: (0.0009) | Acc: (99.99%) (35860/35865)
# Epoch: 19 | Batch_idx: 2400 |  Loss: (0.0009) | Acc: (99.99%) (36010/36015)
# Epoch: 19 | Batch_idx: 2410 |  Loss: (0.0009) | Acc: (99.99%) (36160/36165)
# Epoch: 19 | Batch_idx: 2420 |  Loss: (0.0009) | Acc: (99.99%) (36310/36315)
# Epoch: 19 | Batch_idx: 2430 |  Loss: (0.0009) | Acc: (99.99%) (36460/36465)
# Epoch: 19 | Batch_idx: 2440 |  Loss: (0.0009) | Acc: (99.99%) (36610/36615)
# Epoch: 19 | Batch_idx: 2450 |  Loss: (0.0009) | Acc: (99.99%) (36760/36765)
# Epoch: 19 | Batch_idx: 2460 |  Loss: (0.0009) | Acc: (99.99%) (36910/36915)
# Epoch: 19 | Batch_idx: 2470 |  Loss: (0.0009) | Acc: (99.98%) (37058/37065)
# Epoch: 19 | Batch_idx: 2480 |  Loss: (0.0009) | Acc: (99.98%) (37208/37215)
# Epoch: 19 | Batch_idx: 2490 |  Loss: (0.0009) | Acc: (99.98%) (37358/37365)
# Epoch: 19 | Batch_idx: 2500 |  Loss: (0.0009) | Acc: (99.98%) (37508/37515)
# Epoch: 19 | Batch_idx: 2510 |  Loss: (0.0009) | Acc: (99.98%) (37658/37665)
# Epoch: 19 | Batch_idx: 2520 |  Loss: (0.0009) | Acc: (99.98%) (37808/37815)
# Epoch: 19 | Batch_idx: 2530 |  Loss: (0.0009) | Acc: (99.98%) (37958/37965)
# Epoch: 19 | Batch_idx: 2540 |  Loss: (0.0009) | Acc: (99.98%) (38108/38115)
# Epoch: 19 | Batch_idx: 2550 |  Loss: (0.0009) | Acc: (99.98%) (38258/38265)
# Epoch: 19 | Batch_idx: 2560 |  Loss: (0.0009) | Acc: (99.98%) (38408/38415)
# Epoch: 19 | Batch_idx: 2570 |  Loss: (0.0009) | Acc: (99.98%) (38558/38565)
# Epoch: 19 | Batch_idx: 2580 |  Loss: (0.0009) | Acc: (99.98%) (38708/38715)
# Epoch: 19 | Batch_idx: 2590 |  Loss: (0.0009) | Acc: (99.98%) (38858/38865)
# Epoch: 19 | Batch_idx: 2600 |  Loss: (0.0009) | Acc: (99.98%) (39008/39015)
# Epoch: 19 | Batch_idx: 2610 |  Loss: (0.0009) | Acc: (99.98%) (39158/39165)
# Epoch: 19 | Batch_idx: 2620 |  Loss: (0.0009) | Acc: (99.98%) (39308/39315)
# Epoch: 19 | Batch_idx: 2630 |  Loss: (0.0009) | Acc: (99.98%) (39458/39465)
# Epoch: 19 | Batch_idx: 2640 |  Loss: (0.0009) | Acc: (99.98%) (39608/39615)
# Epoch: 19 | Batch_idx: 2650 |  Loss: (0.0009) | Acc: (99.98%) (39758/39765)
# Epoch: 19 | Batch_idx: 2660 |  Loss: (0.0009) | Acc: (99.98%) (39908/39915)
# Epoch: 19 | Batch_idx: 2670 |  Loss: (0.0009) | Acc: (99.98%) (40058/40065)
# Epoch: 19 | Batch_idx: 2680 |  Loss: (0.0009) | Acc: (99.98%) (40208/40215)
# Epoch: 19 | Batch_idx: 2690 |  Loss: (0.0009) | Acc: (99.98%) (40358/40365)
# Epoch: 19 | Batch_idx: 2700 |  Loss: (0.0009) | Acc: (99.98%) (40508/40515)
# Epoch: 19 | Batch_idx: 2710 |  Loss: (0.0009) | Acc: (99.98%) (40658/40665)
# Epoch: 19 | Batch_idx: 2720 |  Loss: (0.0009) | Acc: (99.98%) (40808/40815)
# Epoch: 19 | Batch_idx: 2730 |  Loss: (0.0009) | Acc: (99.98%) (40958/40965)
# Epoch: 19 | Batch_idx: 2740 |  Loss: (0.0009) | Acc: (99.98%) (41108/41115)
# Epoch: 19 | Batch_idx: 2750 |  Loss: (0.0009) | Acc: (99.98%) (41258/41265)
# Epoch: 19 | Batch_idx: 2760 |  Loss: (0.0009) | Acc: (99.98%) (41408/41415)
# Epoch: 19 | Batch_idx: 2770 |  Loss: (0.0009) | Acc: (99.98%) (41558/41565)
# Epoch: 19 | Batch_idx: 2780 |  Loss: (0.0009) | Acc: (99.98%) (41708/41715)
# Epoch: 19 | Batch_idx: 2790 |  Loss: (0.0009) | Acc: (99.98%) (41858/41865)
# Epoch: 19 | Batch_idx: 2800 |  Loss: (0.0009) | Acc: (99.98%) (42008/42015)
# Epoch: 19 | Batch_idx: 2810 |  Loss: (0.0009) | Acc: (99.98%) (42158/42165)
# Epoch: 19 | Batch_idx: 2820 |  Loss: (0.0009) | Acc: (99.98%) (42308/42315)
# Epoch: 19 | Batch_idx: 2830 |  Loss: (0.0009) | Acc: (99.98%) (42458/42465)
# Epoch: 19 | Batch_idx: 2840 |  Loss: (0.0009) | Acc: (99.98%) (42608/42615)
# Epoch: 19 | Batch_idx: 2850 |  Loss: (0.0009) | Acc: (99.98%) (42758/42765)
# Epoch: 19 | Batch_idx: 2860 |  Loss: (0.0009) | Acc: (99.98%) (42908/42915)
# Epoch: 19 | Batch_idx: 2870 |  Loss: (0.0009) | Acc: (99.98%) (43058/43065)
# Epoch: 19 | Batch_idx: 2880 |  Loss: (0.0009) | Acc: (99.98%) (43208/43215)
# Epoch: 19 | Batch_idx: 2890 |  Loss: (0.0009) | Acc: (99.98%) (43358/43365)
# Epoch: 19 | Batch_idx: 2900 |  Loss: (0.0009) | Acc: (99.98%) (43508/43515)
# Epoch: 19 | Batch_idx: 2910 |  Loss: (0.0009) | Acc: (99.98%) (43658/43665)
# Epoch: 19 | Batch_idx: 2920 |  Loss: (0.0009) | Acc: (99.98%) (43808/43815)
# Epoch: 19 | Batch_idx: 2930 |  Loss: (0.0009) | Acc: (99.98%) (43958/43965)
# Epoch: 19 | Batch_idx: 2940 |  Loss: (0.0009) | Acc: (99.98%) (44108/44115)
# Epoch: 19 | Batch_idx: 2950 |  Loss: (0.0009) | Acc: (99.98%) (44258/44265)
# Epoch: 19 | Batch_idx: 2960 |  Loss: (0.0009) | Acc: (99.98%) (44408/44415)
# Epoch: 19 | Batch_idx: 2970 |  Loss: (0.0009) | Acc: (99.98%) (44558/44565)
# Epoch: 19 | Batch_idx: 2980 |  Loss: (0.0009) | Acc: (99.98%) (44708/44715)
# Epoch: 19 | Batch_idx: 2990 |  Loss: (0.0009) | Acc: (99.98%) (44858/44865)
# Epoch: 19 | Batch_idx: 3000 |  Loss: (0.0009) | Acc: (99.98%) (45008/45015)
# Epoch: 19 | Batch_idx: 3010 |  Loss: (0.0009) | Acc: (99.98%) (45158/45165)
# Epoch: 19 | Batch_idx: 3020 |  Loss: (0.0009) | Acc: (99.98%) (45308/45315)
# Epoch: 19 | Batch_idx: 3030 |  Loss: (0.0009) | Acc: (99.98%) (45458/45465)
# Epoch: 19 | Batch_idx: 3040 |  Loss: (0.0009) | Acc: (99.98%) (45608/45615)
# Epoch: 19 | Batch_idx: 3050 |  Loss: (0.0009) | Acc: (99.98%) (45758/45765)
# Epoch: 19 | Batch_idx: 3060 |  Loss: (0.0009) | Acc: (99.98%) (45908/45915)
# Epoch: 19 | Batch_idx: 3070 |  Loss: (0.0009) | Acc: (99.98%) (46058/46065)
# Epoch: 19 | Batch_idx: 3080 |  Loss: (0.0009) | Acc: (99.98%) (46208/46215)
# Epoch: 19 | Batch_idx: 3090 |  Loss: (0.0009) | Acc: (99.98%) (46358/46365)
# Epoch: 19 | Batch_idx: 3100 |  Loss: (0.0009) | Acc: (99.98%) (46508/46515)
# Epoch: 19 | Batch_idx: 3110 |  Loss: (0.0009) | Acc: (99.99%) (46658/46665)
# Epoch: 19 | Batch_idx: 3120 |  Loss: (0.0009) | Acc: (99.99%) (46808/46815)
# Epoch: 19 | Batch_idx: 3130 |  Loss: (0.0009) | Acc: (99.99%) (46958/46965)
# Epoch: 19 | Batch_idx: 3140 |  Loss: (0.0009) | Acc: (99.99%) (47108/47115)
# Epoch: 19 | Batch_idx: 3150 |  Loss: (0.0009) | Acc: (99.99%) (47258/47265)
# Epoch: 19 | Batch_idx: 3160 |  Loss: (0.0009) | Acc: (99.99%) (47408/47415)
# Epoch: 19 | Batch_idx: 3170 |  Loss: (0.0009) | Acc: (99.99%) (47558/47565)
# Epoch: 19 | Batch_idx: 3180 |  Loss: (0.0009) | Acc: (99.99%) (47708/47715)
# Epoch: 19 | Batch_idx: 3190 |  Loss: (0.0009) | Acc: (99.99%) (47858/47865)
# Epoch: 19 | Batch_idx: 3200 |  Loss: (0.0009) | Acc: (99.99%) (48008/48015)
# Epoch: 19 | Batch_idx: 3210 |  Loss: (0.0009) | Acc: (99.99%) (48158/48165)
# Epoch: 19 | Batch_idx: 3220 |  Loss: (0.0009) | Acc: (99.99%) (48308/48315)
# Epoch: 19 | Batch_idx: 3230 |  Loss: (0.0009) | Acc: (99.99%) (48458/48465)
# Epoch: 19 | Batch_idx: 3240 |  Loss: (0.0009) | Acc: (99.99%) (48608/48615)
# Epoch: 19 | Batch_idx: 3250 |  Loss: (0.0009) | Acc: (99.99%) (48758/48765)
# Epoch: 19 | Batch_idx: 3260 |  Loss: (0.0009) | Acc: (99.99%) (48908/48915)
# Epoch: 19 | Batch_idx: 3270 |  Loss: (0.0009) | Acc: (99.99%) (49058/49065)
# Epoch: 19 | Batch_idx: 3280 |  Loss: (0.0009) | Acc: (99.99%) (49208/49215)
# Epoch: 19 | Batch_idx: 3290 |  Loss: (0.0009) | Acc: (99.99%) (49358/49365)
# Epoch: 19 | Batch_idx: 3300 |  Loss: (0.0009) | Acc: (99.99%) (49508/49515)
# Epoch: 19 | Batch_idx: 3310 |  Loss: (0.0009) | Acc: (99.99%) (49658/49665)
# Epoch: 19 | Batch_idx: 3320 |  Loss: (0.0009) | Acc: (99.99%) (49808/49815)
# Epoch: 19 | Batch_idx: 3330 |  Loss: (0.0009) | Acc: (99.99%) (49958/49965)
# => saving checkpoint
# # TEST : Loss: (0.0915) | Acc: (97.87%) (9787/10000)
# 2 hours 24 mins 12 secs for training
# '\n#plot\nplt.figure(figsize=(10,5))\nplt.title("Training and Validation Loss")\nplt.plot(val_losses,label="val")\nplt.plot(train_losses,label="train")\nplt.xlabel("iterations")\nplt.ylabel("Loss")\nplt.legend()\nplt.show()\n'
